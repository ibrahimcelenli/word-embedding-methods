# %% [markdown]
# ## Fasttext Algorithm

# %% [markdown]
# <img src="image/fasttext.png",width=800,height=800>

# %%
# import modules & set up logging
import gensim, logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import time

# %% [markdown]
# #### https://radimrehurek.com/gensim/models/fasttext.html
#
# gensim.models.fasttext.FastText(sentences=None, corpus_file=None, sg=0, hs=0, size=100,
# alpha=0.025, window=5,min_count=5, max_vocab_size=None, word_ngrams=1, sample=0.001, seed=1, workers=3,min_alpha=0.0001, negative=5, ns_exponent=0.75, cbow_mean=1, hashfxn=<built-in function hash>, iter=5, null_word=0, min_n=3, max_n=6, sorted_vocab=1, bucket=2000000, trim_rule=None, batch_words=10000, callbacks=())

# %% [markdown]
# ## Example

# %%
from gensim.test.utils import common_texts
from gensim.models import FastText

common_texts = [['ilk', 'cümle'], ['ikinci', 'cümle']]
model = FastText(common_texts, size=4, window=3, min_count=1)
# Out:
# 2018-10-06 02:09:19,546 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-10-06 02:09:19,548 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)
# 2018-10-06 02:09:19,549 : INFO : collecting all words and their counts
# 2018-10-06 02:09:19,550 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-10-06 02:09:19,551 : INFO : collected 3 word types from a corpus of 4 raw words and 2 sentences
# 2018-10-06 02:09:19,551 : INFO : Loading a fresh vocabulary
# 2018-10-06 02:09:19,552 : INFO : min_count=1 retains 3 unique words (100% of original 3, drops 0)
# 2018-10-06 02:09:19,552 : INFO : min_count=1 leaves 4 word corpus (100% of original 4, drops 0)
# 2018-10-06 02:09:19,553 : INFO : deleting the raw counts dictionary of 3 items
# 2018-10-06 02:09:19,554 : INFO : sample=0.001 downsamples 3 most-common words
# 2018-10-06 02:09:19,555 : INFO : downsampling leaves estimated 0 word corpus (5.7% of prior 4)
# 2018-10-06 02:09:19,555 : INFO : estimated required memory for 3 words, 38 buckets and 4 dimensions: 2652 bytes
# 2018-10-06 02:09:19,556 : INFO : resetting layer weights
# 2018-10-06 02:09:19,566 : INFO : Total number of ngrams is 38
# 2018-10-06 02:09:19,583 : INFO : training model with 3 workers on 3 vocabulary and 4 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# 2018-10-06 02:09:19,585 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:09:19,585 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:09:19,586 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:09:19,586 : INFO : EPOCH - 1 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-10-06 02:09:19,588 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:09:19,589 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:09:19,589 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:09:19,590 : INFO : EPOCH - 2 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-10-06 02:09:19,592 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:09:19,593 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:09:19,593 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:09:19,594 : INFO : EPOCH - 3 : training on 4 raw words (1 effective words) took 0.0s, 364 effective words/s
# 2018-10-06 02:09:19,597 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:09:19,598 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:09:19,598 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:09:19,599 : INFO : EPOCH - 4 : training on 4 raw words (1 effective words) took 0.0s, 362 effective words/s
# 2018-10-06 02:09:19,601 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:09:19,601 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:09:19,602 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:09:19,603 : INFO : EPOCH - 5 : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-10-06 02:09:19,603 : INFO : training on a 20 raw words (2 effective words) took 0.0s, 101 effective words/s
# 2018-10-06 02:09:19,604 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
print(model)
print("*"*50)
print(model.wv.vocab)
# Out:
# FastText(vocab=3, size=4, alpha=0.025)
# **************************************************
# {'ilk': <gensim.models.keyedvectors.Vocab object at 0x7f4b46eebb00>, 'cümle': <gensim.models.keyedvectors.Vocab object at 0x7f4b46eebc50>, 'ikinci': <gensim.models.keyedvectors.Vocab object at 0x7f4b46eebdd8>}

# %% [markdown]
# # Project

# %% [markdown]
# <img src="image/kemik.png",width=500,height=500>

# %% [markdown]
# dataset : [3000 Turkish Tweets for sentiment analysis (3 classes)](http://www.kemik.yildiz.edu.tr/?id=28)

# %%
# data load

from glob import glob

tweet_list = []

for index, file in enumerate(glob('data/3000tweet/raw_texts/**/*.txt', recursive=True)):                                                             # labels
    tweet_list.append((open(file, encoding="windows-1254").read().replace('\n', ' ').strip().lower()))      # tweets

print("3000 tweet  :  ", len(tweet_list))
# Out:
# 3000 tweet  :   3000

# %%
# preprocessing

import Stemmer
import re


def splitIntoStem(message):
    
    return [removeNumeric(stripEmoji(singleCharacterRemove(removePunctuation
                                                           (removeHyperlinks
                                                            (removeHashtags
                                                             (removeUsernames
                                                              (stemWord(word)))))))) for word in message.split()]

def stemWord(tweet):

    ################################## for turkish
    #stemmer = Stemmer.Stemmer('turkish')
    #return stemmer.stemWord(tweet).lower()
    
    return tweet.lower()

#remove usernames
def removeUsernames(tweet):
    return re.sub('@[^\s]+', '', tweet)


#remove hashtag
def removeHashtags(tweet):
    return re.sub(r'#[^\s]+', '', tweet)

#remove link
def removeHyperlinks(tweet):
    return re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', tweet)

def removeNumeric(value):
    blist2 = [item for item in value if not item.isdigit()]
    blist3 = "".join(blist2)
    return blist3

def removePunctuation(tweet):

    return re.sub(r'[^\w\s]','',tweet)

def singleCharacterRemove(tweet):
    return re.sub(r'(?:^| )\w(?:$| )', ' ', tweet)


def stripEmoji(text):

    RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    return RE_EMOJI.sub(r'', text)

# %%
tweet_list[0]
# Out:
# '#turkcell superonline bir milyon evin kapisina fiber internet goturdu bizde niye yok bize niye getirmiyorlar :))'

# %%
for i,k in enumerate(tweet_list):
    tweet_list[i] = " ".join(splitIntoStem(k)).split()

# %%
tweet_list[0]
# Out:
# ['superonline',
#  'bir',
#  'milyon',
#  'evin',
#  'kapisina',
#  'fiber',
#  'internet',
#  'goturdu',
#  'bizde',
#  'niye',
#  'yok',
#  'bize',
#  'niye',
#  'getirmiyorlar']

# %%
import string

def sumTweetWords():
    new_value = ""
    for i in tweet_list:
        value = " ".join(i) 
        new_value = new_value + " " +value
    print("len(tweet_list) : ",len(new_value.split()))

sumTweetWords()
# Out:
# len(tweet_list) :  32588

# %%
# remove stopwords

from nltk.corpus import stopwords

def removeStopWords(tweet_list):
    
    filtered_stopwords = []
    
    stop_words = stopwords.words('turkish')

    stop_words.append("bir")
    stop_words.append("iki")
    stop_words.append("üç")
    stop_words.append("dört")
    stop_words.append("beş")
    stop_words.append("altı")
    stop_words.append("yedi")
    stop_words.append("sekiz")
    stop_words.append("dokuz")
    stop_words.append("on")
    
    print("stop_words : ",stop_words)
    
    for i in tweet_list:
        filtered_sentence = [w for w in i if not w in stop_words]
        filtered_stopwords.append(filtered_sentence)
    return filtered_stopwords

tweet_list = removeStopWords(tweet_list)
# Out:
# stop_words :  ['acaba', 'ama', 'aslında', 'az', 'bazı', 'belki', 'biri', 'birkaç', 'birşey', 'biz', 'bu', 'çok', 'çünkü', 'da', 'daha', 'de', 'defa', 'diye', 'eğer', 'en', 'gibi', 'hem', 'hep', 'hepsi', 'her', 'hiç', 'için', 'ile', 'ise', 'kez', 'ki', 'kim', 'mı', 'mu', 'mü', 'nasıl', 'ne', 'neden', 'nerde', 'nerede', 'nereye', 'niçin', 'niye', 'o', 'sanki', 'şey', 'siz', 'şu', 'tüm', 've', 'veya', 'ya', 'yani', 'bir', 'iki', 'üç', 'dört', 'beş', 'altı', 'yedi', 'sekiz', 'dokuz', 'on']

# %%
tweet_list
# Out:
# [['superonline',
#   'milyon',
#   'evin',
#   'kapisina',
#   'fiber',
#   'internet',
#   'goturdu',
#   'bizde',
#   'yok',
#   'bize',
#   'getirmiyorlar'],
#  ['evde',
#   'olmamasi',
#   'gereken',
#   'şeyturkcell',
#   'digiturk',
#   'keriz',
#   'anten',
#   'çiçeği'],
#  ['ucuz', 'iphone', 's', 'fiyatını', 'hangi', 'operatör', 'sunuyor', 'ohasın'],
#  ['gb', 'internet', 'pakedim', 'bitti', 'lanet', 'turkcell'],
#  ['ay',
#   'ben',
#   'size',
#   'tl',
#   'yakin',
#   'para',
#   'oduyorum',
#   'hizmet',
#   'istiyorum'],
#  ['inceledimmm',
#   'kiyasladimm',
#   'gercktnn',
#   'cokk',
#   'yuksekk',
#   'rakiplerine',
#   'gore',
#   'bi',
#   'fiyatlarla',
#   'almak',
#   'akilkari',
#   'degl',
#   'sanrm'],
#  ['lanet', 'olasın', 'turkcell', 'dedim'],
#  ['dur',
#   'turkcelle',
#   'mesaj',
#   'atıyım',
#   'sevgilisinden',
#   'geldi',
#   'sansın',
#   'enayi'],
#  ['gerçekten',
#   'ttnetden',
#   'hızlıysa',
#   'esos',
#   'geçecem',
#   'superonlinea',
#   'sinir',
#   'oldum',
#   'valla',
#   'kadar',
#   'yavaş',
#   'olamaz',
#   'birnet'],
#  ['oc',
#   'musteri',
#   'hizmetleri',
#   'kukla',
#   'ettiniz',
#   'amk',
#   'turkcell',
#   'beni',
#   'sessimden',
#   'tanirmis'],
#  ['bre',
#   'turkcell',
#   'tam',
#   'bi',
#   'hırsızsın',
#   'seni',
#   'bi',
#   'kullanani',
#   'esekler',
#   'kovalasin'],
#  ['kardeşim',
#   'tanıdıgım',
#   'bi',
#   'piskiyatır',
#   'var',
#   'numarasını',
#   'vereyim',
#   'tansaşturkcellavea',
#   'vbden',
#   'gelen',
#   'mesajları',
#   'ona',
#   'atarsın'],
#  ['oç', 'oldu', 'günde', 'bin', 'çisi', 'korkuttu', 'seni'],
#  ['turkcellde',
#   'iyice',
#   'uçtu',
#   'yok',
#   'yükle',
#   'al',
#   'yükle',
#   'al',
#   'hesaplamalarıma',
#   'göre',
#   'bin',
#   'tl',
#   'yüklesem',
#   'şirketi'],
#  ['canım',
#   'sevgilim',
#   'turkcell',
#   'yeter',
#   'artık',
#   'terket',
#   'beni',
#   'birinden',
#   'msj',
#   'beklediğim',
#   'bi',
#   'zaman',
#   'atarsın',
#   'msjlarını'],
#  ['bende', 'turkcellliyim', 'bende', 'sevdadan', 'gram', 'yok'],
#  ['ôyle',
#   'değil',
#   'iste',
#   'kısmen',
#   'anlatırım',
#   'geldigimde',
#   'ayrıntıları',
#   'turkcell',
#   'hattim',
#   'hala',
#   'iptal'],
#  ['beşiktaşın',
#   'orta',
#   'yerindeyim',
#   'internet',
#   'edge',
#   'arada',
#   'edgeden',
#   'hallice',
#   'g',
#   'çekiyor',
#   'teşekkürler'],
#  ['ipragaz',
#   'reklamı',
#   'muhteşem',
#   'olmuş',
#   'süper',
#   'abiturkcell',
#   'reklam',
#   'görsün'],
#  ['yok',
#   'arasaniz',
#   'olacak',
#   'bilmiyorum',
#   'saattir',
#   'baglanti',
#   'kuramiyorum',
#   'yine',
#   'wifi',
#   'deyim',
#   'vinn',
#   'diyosunuz',
#   'kanser',
#   'olur',
#   'inssn'],
#  ['bunların', 'böle', 'digiturk', 'turkcel', 'telekom', 'soyguncu'],
#  ['turkcell', 'tam', 'kaltak'],
#  ['yillik',
#   'tecrubeme',
#   'dayanarak',
#   'söyleyebilirim',
#   'yerde',
#   'çeker',
#   'büyük',
#   'yalan',
#   'turkcell',
#   'bakirköyde',
#   'cekmiyorgüneslide',
#   'hic',
#   'cekmiyor'],
#  ['önce',
#   'bedava',
#   'dakikan',
#   'bitti',
#   'dedin',
#   'sonra',
#   'eksilmeyen',
#   'dk',
#   'verdin',
#   'şimdi',
#   'dakikan',
#   'kaldı',
#   'diyorsunnapmaya',
#   'çalışıyorsun',
#   'turkcell'],
#  ['işim',
#   'gücüm',
#   'yok',
#   'turkcell',
#   'in',
#   'fizydeki',
#   'telefondan',
#   'sms',
#   'olarak',
#   'ücretsiz',
#   'şarkı',
#   'paylaşma',
#   'uygulamasını',
#   'deniyorum',
#   'hala',
#   'kimse',
#   'teşekkür',
#   'etmedi'],
#  ['zaman',
#   'yoğun',
#   'şeyler',
#   'yaşasan',
#   'an',
#   'bi',
#   'msj',
#   'gelir',
#   'atan',
#   'turkcelldir'],
#  ['inanır',
#   'mısınız',
#   'anda',
#   'internet',
#   'paketim',
#   'yok',
#   'hatta',
#   'tlmden',
#   'gitmiyor',
#   'turkcell',
#   'bizi',
#   'kazıklayacak',
#   'canım'],
#  ['türksel',
#   'bugün',
#   'bildiğin',
#   'taciz',
#   'etti',
#   'beni',
#   'dk',
#   'rahat',
#   'vermedi'],
#  ['zaman',
#   'turkcellin',
#   'yılbaşı',
#   'öztürkcell',
#   'reklamını',
#   'izle',
#   'iyice',
#   'dumur',
#   'ol',
#   'paralel',
#   'evrendeki',
#   'berbat',
#   'turkcellin',
#   'reklamı'],
#  ['oyy', 'turkcel', 'sebekeneeee'],
#  ['ısık',
#   'hızında',
#   'oldugunu',
#   'ıddıa',
#   'ettıklerı',
#   'ınternetı',
#   'gunde',
#   'baglayamıyorlar'],
#  ['hesapla',
#   'haftalık',
#   'esenköy',
#   'tatili',
#   'turkcell',
#   'vınn',
#   'paketi',
#   'bana',
#   'nerdeyse',
#   'tlye',
#   'mal',
#   'olmuş',
#   'durumda',
#   'ehhayat',
#   'kazıklanınca',
#   'güzell',
#   'lalalalaa'],
#  ['sacma',
#   'sapan',
#   'sinir',
#   'bozucu',
#   'reklam',
#   'furyasi',
#   'nedir',
#   'sahanli',
#   'turkcell',
#   'bonus',
#   'card',
#   'kafa',
#   'reklami',
#   'aytac',
#   'iticisiniz'],
#  ['arada',
#   'süperonline',
#   'internet',
#   'gb',
#   'downloaddan',
#   'sonra',
#   'hızınıı',
#   'mbt',
#   'ten',
#   'mbt',
#   'düşürüyomuşhaberiniz',
#   'olasınırsız',
#   'gaza',
#   'gelmeyin'],
#  ['turkcell',
#   'iyice',
#   'aştı',
#   'kendini',
#   'dakikada',
#   'mesaj',
#   'gönderilir',
#   'mi',
#   'insan',
#   'içlerinden',
#   'başkasındandır',
#   'umutlanıyor',
#   'insafsızlaaaaar'],
#  ['oyle', 'cevap', 'yazdim', 'tcellesize', 'ihtiyacim', 'yok'],
#  ['bi', 'turksel', 'bi', 'dijiturkten', 'cektigim', 'kadaaar'],
#  ['denedim',
#   'bişeyi',
#   'paylaşmayı',
#   'sürekli',
#   'hata',
#   'verdi',
#   'vay',
#   'anasını',
#   'sıçıyım',
#   'internetine',
#   'türksel'],
#  ['internet',
#   'paketim',
#   'var',
#   'sms',
#   'paketim',
#   'var',
#   'liralarımı',
#   'sömürüyosun',
#   'gerizekalı',
#   'turkcell'],
#  ['saat', 'fark', 'etmeden', 'msj', 'atana', 'turkcell', 'denir'],
#  ['turkcelli',
#   'kiniyorum',
#   'ipad',
#   'icin',
#   'yapmis',
#   'oldugunuz',
#   'kampanyanin',
#   'sadece',
#   'faturali',
#   'hatlar',
#   'icin',
#   'gecerli',
#   'olmasi',
#   'kadar',
#   'sacma',
#   'bi',
#   'durum',
#   'olamaz'],
#  ['turkcell',
#   'cok',
#   'ii',
#   'sankiher',
#   'ay',
#   'paketlerinin',
#   'kati',
#   'para',
#   'geliosurekli',
#   'yuksek',
#   'bi',
#   'paket',
#   'almaya',
#   'mecbur',
#   'birakiosun'],
#  ['bütün',
#   'turkcellilerde',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'çalıyor',
#   'hoşuma',
#   'giden',
#   'müzikten',
#   'midem',
#   'bulanmaya',
#   'başladı'],
#  ['sorma', 'turkcele', 'inat', 'hat', 'kulaniyorum', 'turkcell', 'tl'],
#  ['sabahın',
#   'inde',
#   'milli',
#   'piyango',
#   'sonucu',
#   'gönderen',
#   'bilyonerturkcell',
#   'bari',
#   'ikramiye',
#   'kazandınde',
#   'boşuna',
#   'uyanmamış',
#   'olaydım'],
#  ['abone',
#   'olmak',
#   'isteyen',
#   'arkadaslarim',
#   'oncelikle',
#   'benim',
#   'tecrubelerime',
#   'basvursunlar',
#   'eminim',
#   'vevirmeli',
#   'modemle',
#   'baglanavaklardir'],
#  ['yetkili',
#   'benim',
#   'sersenişlerimi',
#   'duyup',
#   'cevap',
#   'vermemiş',
#   'hani',
#   'hizmet',
#   'kalitesi',
#   'yirim',
#   'senin',
#   'hizetinide',
#   'kalitenide',
#   'tl'],
#  ['turkcellin', 'işi', 'gücü', 'yok', 'sürekli', 'bana', 'çalışıyor', 'dd'],
#  ['ayın',
#   'sında',
#   'hala',
#   'eline',
#   'ulaşmayacaksa',
#   'sında',
#   'geliyor',
#   'reklam',
#   'yapma',
#   'turkcell'],
#  ['sırf',
#   'uygulama',
#   'mesajlarınız',
#   'yüzünden',
#   'bıktım',
#   'dedirttiniz',
#   'bravo'],
#  ['mesajlarım', 'iletilmiyor', 'boktan', 'operatördür', 'turkcell'],
#  ['hat',
#   'almayın',
#   'salaklıp',
#   'edipteen',
#   'büyük',
#   'yanlışı',
#   'yaparsınızbildiğiniz',
#   'adamı',
#   'yağlı',
#   'kazığa',
#   'oturtuyorlar'],
#  ['sahsen',
#   'hayat',
#   'paylasinca',
#   'guzel',
#   'falan',
#   'degil',
#   'turkcell',
#   'buyuk',
#   'bi',
#   'hata',
#   'yapiyoo',
#   'mesela',
#   'ben',
#   'cikolatami',
#   'paylasinca',
#   'kat',
#   'kotu',
#   'oluyorum'],
#  ['hafta',
#   'icerisinde',
#   'kurulum',
#   'yapacaktinizaraya',
#   'bayram',
#   'tatili',
#   'girdi',
#   'zamandan',
#   'zamana',
#   'arayan',
#   'gelen',
#   'var'],
#  ['yok',
#   'yolda',
#   'kaldık',
#   'gel',
#   'lastik',
#   'değiş',
#   'desek',
#   'anlarız',
#   'zor',
#   'iş',
#   'basit',
#   'turkcell',
#   'seni',
#   'mahvetmiş',
#   'adamım'],
#  ['inanın',
#   'benimde',
#   'konuştuğum',
#   'herkes',
#   'trcell',
#   'kullanıyor',
#   'vodafone',
#   'bence',
#   'iyi',
#   'operatör',
#   'tabiki',
#   'karar',
#   'sizin',
#   'ist',
#   'denmisnz'],
#  ['sabah',
#   'turkcel',
#   'msj',
#   'atmadı',
#   'battı',
#   'herhalde',
#   'dıe',
#   'dusundum',
#   'yğunukdan',
#   'gecikti',
#   'herhald',
#   'merak',
#   'ediyoruz',
#   'turkcell',
#   'kadar',
#   'bekletme',
#   'sabahları'],
#  ['sattir',
#   'telefonuma',
#   'msj',
#   'gelip',
#   'duruyo',
#   'seferinde',
#   'turkcell',
#   'oluyo',
#   'bende',
#   'seferinde',
#   'heyecanlanıyorum',
#   'bundan',
#   'sonrakine',
#   'bakmıycam'],
#  ['dir', 'dir', 'dir'],
#  ['turkcelliler', 'twitteri', 'cepten', 'kullanamıyorlaaarr'],
#  ['dostum',
#   'durduk',
#   'yerde',
#   'mb',
#   'internetimi',
#   'turkcell',
#   'yarın',
#   'gidip',
#   'söyliycem',
#   'düzeltmezlere',
#   'aveaya',
#   'gecıyorum'],
#  ['internet',
#   'kadar',
#   'yavaş',
#   'premium',
#   'accountdan',
#   'download',
#   'yaptığım',
#   'halde',
#   'free',
#   'userdan',
#   'bi',
#   'farkım',
#   'yok',
#   'resmen'],
#  ['dipnot', 'turkcellin', 'net', 'hizina', 'koyayim'],
#  ['mesaj', 'atacam', 'salak', 'kadar', 'sevinecek', 'turkcell'],
#  ['paylaşamıyoruz',
#   'tcell',
#   'odamdan',
#   'çekmiyor',
#   'alo',
#   'demek',
#   'dk',
#   'harcayınca',
#   'paylaşmış',
#   'olmuyoruz'],
#  ['turkcelli',
#   'benzer',
#   'sebeplerle',
#   'biraktim',
#   'alternatifleri',
#   'mi',
#   'iyi',
#   'tartisilirtuketiciyi',
#   'koruyan',
#   'platformlara',
#   'ihtiyacimiz',
#   'var'],
#  ['bugun',
#   'turkcell',
#   'musteri',
#   'hizmetlerinin',
#   'beni',
#   'aramasi',
#   'bilgisayar',
#   'takildi',
#   'kaldi',
#   'sanirim',
#   'otomatige',
#   'bagladi',
#   'imdatt'],
#  ['normalde',
#   'küçük',
#   'harflerle',
#   'sms',
#   'atan',
#   'turkcellin',
#   'fatura',
#   'tutarı',
#   'yada',
#   'son',
#   'ödeme',
#   'tarihi',
#   'bilgisi',
#   'attığı',
#   'smslerin',
#   'büyük',
#   'harfle',
#   'olması'],
#  ['turkcellin',
#   'paket',
#   'reklamlarıni',
#   'duymak',
#   'zorunda',
#   'miyimbir',
#   'soru',
#   'sormak',
#   'anlamıyorum',
#   'biraz',
#   'saygı',
#   'cırtcell',
#   'müşteri',
#   'hizmeti'],
#  ['eleştirenlere',
#   'inat',
#   'turkcell',
#   'savaşınızdaki',
#   'gelişmeleri',
#   'tweetlemenizi',
#   'bekleyenler',
#   'var'],
#  ['superonline', 'fiber', 'rezalet', 'devam', 'ediyor'],
#  ['sabah',
#   'afyonum',
#   'patlamadan',
#   'tlf',
#   'çalıp',
#   'actiginda',
#   'turkcellin',
#   'band',
#   'kaydı',
#   'olduğunu',
#   'anladığım',
#   'an',
#   'içimden',
#   'söylediklerim'],
#  ['olur',
#   'turkcell',
#   'bunu',
#   'reklam',
#   'kampanyalarında',
#   'kullanmasın',
#   'zira',
#   'bütçeden',
#   'dolayı',
#   'kanalda',
#   'yayınlanıyor'],
#  ['onun',
#   'aynısını',
#   'bizede',
#   'yaptılar',
#   'turkcel',
#   'gerçekten',
#   'dolandırıcı',
#   'yaaa',
#   'paket',
#   'bitti',
#   'madem',
#   'haber',
#   'ver',
#   'demi'],
#  ['büyük', 'kuş', 'türksel', 'işte', 'utanmasa', 'serçeyi', 'yiyecek'],
#  ['faturali',
#   'hattima',
#   'hic',
#   'indirim',
#   'hediye',
#   'alamazken',
#   'tl',
#   'yukleyen',
#   'hazirkartliya',
#   'milyonlarca',
#   'dakika',
#   'hediye'],
#  ['in',
#   'benle',
#   'alıp',
#   'veremedigi',
#   'nedir',
#   'is',
#   'yerimde',
#   'çekmez',
#   'evimde',
#   'çekmez',
#   'bide',
#   'bangir',
#   'bangir',
#   'reklam',
#   'yapar',
#   'hd',
#   'ses',
#   'kalitesi',
#   'palavra'],
#  ['gündür',
#   'aynı',
#   'saatte',
#   'telefonumun',
#   'bağlantısı',
#   'komple',
#   'gidiyor',
#   'vssıkıntı',
#   'oluyorcanımı',
#   'sıkma',
#   'turkcellşuanda',
#   'g',
#   'yok',
#   'meselâ'],
#  ['turkcell',
#   'muzikten',
#   'sarki',
#   'hediye',
#   'mesaji',
#   'fake',
#   'mi',
#   'emin',
#   'olamadim',
#   'durduk',
#   'yere',
#   'hediye',
#   'yollasin',
#   'turkcell'],
#  ['bugün', 'turkcell', 'mesaj', 'atmadı', 'kesin', 'aldatıyo', 'amk'],
#  ['zaman',
#   'telefonlar',
#   'makul',
#   'fiyata',
#   'elimize',
#   'gececekhem',
#   'ay',
#   'taahut',
#   'hemde',
#   'dunyanin',
#   'faturasi',
#   'odeniyorbiz',
#   'mi',
#   'cok',
#   'safiz'],
#  ['birini',
#   'aradigimda',
#   'sinyal',
#   'sesinden',
#   'sonra',
#   'mesaj',
#   'birakinizi',
#   'duyduktan',
#   'hemen',
#   'sonra',
#   'gelen',
#   'mesaj',
#   'turkcellin',
#   'sapik',
#   'oldugu',
#   'izlenimi',
#   'uyandiriyor'],
#  ['oç', 'turkcell', 'facebokdan', 'para', 'alıyo'],
#  ['turkcell',
#   'cagrı',
#   'merkezi',
#   'beni',
#   'deli',
#   'ediyor',
#   'bi',
#   'türlü',
#   'anlaşamyruzzzzzzz'],
#  ['dileğim',
#   'superonline',
#   'turkcell',
#   'ttnet',
#   'vb',
#   'firmaların',
#   'sizi',
#   'arayacağız',
#   'demek',
#   'yerine',
#   'direk',
#   'burdan',
#   'cevap',
#   'vermesi',
#   'şeklinde'],
#  ['cok', 'ibnesin', 'turkcellzalımsın', 'turkcell'],
#  ['benden', 'aldıklarını', 'geri', 'ver', 'turkcell', 'âmin'],
#  ['iletişim',
#   'bilgilerimi',
#   'ben',
#   'size',
#   'iletim',
#   'iletmesine',
#   'superonlineın',
#   'yaptıkları',
#   'geçeli',
#   'ay',
#   'olmamasına',
#   'rağmen',
#   'değil',
#   'değil'],
#  ['gece',
#   'saat',
#   'mesaj',
#   'atayımda',
#   'sevgılısı',
#   'attı',
#   'sansın',
#   'gerızekalı',
#   'turkcell'],
#  ['sebepsiz',
#   'yere',
#   'hattımı',
#   'aramaya',
#   'kapattı',
#   'ay',
#   'önce',
#   'verdiğim',
#   'evrak',
#   'fotokopisini',
#   'tekrar',
#   'istiyor',
#   'günümüz',
#   'derebeyi',
#   'lanet',
#   'adamlar'],
#  ['sadece',
#   'turkcell',
#   'mesaj',
#   'atiyorsa',
#   'yalniz',
#   'kalmissın',
#   'demektir'],
#  ['hız',
#   'testi',
#   'veren',
#   'saçma',
#   'sapan',
#   'sitelerle',
#   'şekilde',
#   'bağlantılı',
#   'olabilir',
#   'sitelerde',
#   'hızınız',
#   'yuksek',
#   'gmrünebilir'],
#  ['uzaylı',
#   'gelse',
#   'turkcell',
#   'reklamlarını',
#   'izlese',
#   'müşterilerine',
#   'ay',
#   'sonu',
#   'kol',
#   'fatura',
#   'göndermiyor',
#   'sabah',
#   'öperek',
#   'uyandırıyor',
#   'sanır'],
#  ['nerden',
#   'alacağını',
#   'bilmem',
#   'turkcellden',
#   'kesinlikle',
#   'almaadamlar',
#   'ipadiphoneblackberry',
#   'ürünlerde',
#   'heryerden',
#   'tl',
#   'fazla'],
#  ['kamil',
#   'koçtürkcell',
#   'bilet',
#   'alana',
#   'bilet',
#   'bedava',
#   'kampanyası',
#   'kocaman',
#   'kandırmacadırayip'],
#  ['önce',
#   'şimdi',
#   'turkcell',
#   'özcan',
#   'denizden',
#   'geliyor',
#   'sen',
#   'beni',
#   'öldürcen',
#   'mi',
#   'çıldırtcan',
#   'canım'],
#  ['bayilik',
#   'sisteminiz',
#   'var',
#   'annemin',
#   'kimlik',
#   'bilgilerine',
#   'imzasına',
#   'kadar',
#   'şeyi',
#   'kopya',
#   'etmişler'],
#  ['aklıma',
#   'gece',
#   'gıttıgımız',
#   'zafer',
#   'plazadakı',
#   'turkcell',
#   'subesındekı',
#   'kufur',
#   'eden',
#   'calısan',
#   'geldı',
#   'lan'],
#  ['paragoz', 'turkcell', 'nasi', 'kacirdi', 'firsati', 'hayyyyret'],
#  ['iphone',
#   's',
#   'satısa',
#   'cıktı',
#   'inanılmaz',
#   'gercek',
#   'ucuza',
#   'satan',
#   'turkcellacaba',
#   'bize',
#   'nası',
#   'yol',
#   'su',
#   'elektrik',
#   'olarak',
#   'doncek',
#   'durum'],
#  ['soruturksel',
#   'win',
#   'dan',
#   'memnun',
#   'olan',
#   'allahin',
#   'kulu',
#   'varmi',
#   'cevap',
#   'var',
#   'lan',
#   'cevap',
#   'turkselin',
#   'patronu',
#   'dikkatini',
#   'çeker'],
#  ['turkselde',
#   'gecırıyoda',
#   'geciriyor',
#   'fatura',
#   'gelıyor',
#   'bigecırmeyen',
#   'sen',
#   'kalmıstın',
#   'türksel',
#   'sende',
#   'gecir',
#   'okey'],
#  ['herseyleri',
#   'problem',
#   'modem',
#   'iade',
#   'edecegiz',
#   'timlerde',
#   'geziyoruz',
#   'onun',
#   'sifresi',
#   'yok',
#   'bunun',
#   'bilmemne',
#   'elemani',
#   'yok',
#   'olum',
#   'resmen'],
#  ['bugün', 'turkcell', 'mesaj', 'atmadı', 'kesin', 'başkası', 'var'],
#  ['sayın',
#   'genel',
#   'müdür',
#   'ben',
#   'turkcell',
#   'kullanıcısıyım',
#   'hatay',
#   'reyhanlı',
#   'yaşamaktayım',
#   'bulunduğumuz',
#   'yerde',
#   'malesef',
#   'turkcell'],
#  ['alara',
#   'şimdi',
#   'derin',
#   'nefes',
#   'al',
#   'beynine',
#   'oksijen',
#   'gitsin',
#   'ayrıca',
#   'turkcell',
#   'bana',
#   'bokluk',
#   'yaptı'],
#  ['turkcell',
#   'nası',
#   'çeker',
#   'lan',
#   'yerden',
#   'çekmiyor',
#   'adam',
#   'reklama',
#   'verdiği',
#   'parayla',
#   'antenleri',
#   'düzeltse',
#   'amp'],
#  ['facebook',
#   'kapanıyo',
#   'sms',
#   'tl',
#   'smsi',
#   'olmayanlar',
#   'facebooktan',
#   'mesaj',
#   'atamıcağı',
#   'sms',
#   'yapmak',
#   'zorunda',
#   'olduğumuzu',
#   'düşünmüştür',
#   'kesin',
#   'oç',
#   'türksel'],
#  ['ariköy',
#   'sitesi',
#   'akkavak',
#   'sokak',
#   'no',
#   'uskumruköy',
#   'sariyerde',
#   'telefon',
#   'cekmiyo',
#   'aydir',
#   'ariyorum',
#   'sizi',
#   'bi',
#   'vericiyi',
#   'tamir',
#   'edemediniz'],
#  ['yıllık',
#   'aboneniz',
#   'olarak',
#   'sizinle',
#   'ilişkimi',
#   'kesiyorum',
#   'rakipleriniz',
#   'karşısında',
#   'erimenizi',
#   'keyifle',
#   'izleyeceğim'],
#  ['numara',
#   'tasima',
#   'reklamiyla',
#   'feci',
#   'gol',
#   'atmis',
#   'avea',
#   'turkcel',
#   'vodafon',
#   'araya',
#   'gelse',
#   'cikaramaz'],
#  ['hay',
#   'baslicam',
#   'senin',
#   'sagladgn',
#   'g',
#   'ye',
#   'deee',
#   'cekim',
#   'gucune',
#   'dee'],
#  ['turksel',
#   'beni',
#   'sesimden',
#   'tanıranlamadık',
#   'lutfen',
#   'yenıden',
#   'deneyın',
#   'turksel',
#   'benı',
#   'sesımd',
#   'benim',
#   'ben',
#   'döl',
#   'ziyanı',
#   'tanımadın',
#   'mıaa',
#   'turk',
#   'kızı',
#   'merve'],
#  ['besiktas',
#   'metropol',
#   'subeniz',
#   'oldukca',
#   'ukela',
#   'turkcele',
#   'hic',
#   'yakismadi',
#   'calisanlariniz',
#   'yurt',
#   'disi',
#   'paketlerini',
#   'bilmiyorlae'],
#  ['bana',
#   'tl',
#   'fatura',
#   'gelmiş',
#   'resmen',
#   'salak',
#   'yerine',
#   'koyuyor',
#   'adamı',
#   'var'],
#  ['vallahi',
#   'gizlice',
#   'çakallık',
#   'yapmasına',
#   'gerek',
#   'yok',
#   'turkcell',
#   'açık',
#   'açık',
#   'sömürüyor',
#   'zaten',
#   'bizid'],
#  ['yok', 'cnm', 'turkcell', 'öyle', 'malesefs'],
#  ['ozmnn', 'turkcell', 'cok', 'eslilikten', 'yana'],
#  ['ekran',
#   'jelatini',
#   'turkcellde',
#   'lira',
#   'iken',
#   'telefoncuda',
#   'lira',
#   'kazık',
#   'kol',
#   'boyu'],
#  ['iphone',
#   's',
#   'reklamında',
#   'sadece',
#   'kameraya',
#   'dikkat',
#   'çekmesisanki',
#   'iphone',
#   'başka',
#   'işe',
#   'yaramıyormuş',
#   'havası',
#   'veriyorbeceriksiz',
#   'bi',
#   'reklam'],
#  ['lanet',
#   'olsun',
#   'turkcell',
#   'özel',
#   'hizmet',
#   'merkezi',
#   'gecen',
#   'gün',
#   'yazdıgım',
#   'iyi',
#   'seyleri',
#   'geri',
#   'aliyorum'],
#  ['evett',
#   'katılıyorum',
#   'mehmetcim',
#   'turkcell',
#   'in',
#   'cekeme',
#   'gücü',
#   'mükemmelll',
#   'hic',
#   'bi',
#   'yerde',
#   'cekmio'],
#  ['alana',
#   'kadar',
#   'müşterimsin',
#   'sonra',
#   'halin',
#   'varsa',
#   'gör',
#   'diyen',
#   'anlayış',
#   'vee',
#   'numara',
#   'taşıma',
#   'numaralarına',
#   'dikkat'],
#  ['mb',
#   'limitsiz',
#   'internet',
#   'bağlantsına',
#   'kota',
#   'koyan',
#   'zihniyeti',
#   'kınıyorum'],
#  ['türkcellden',
#   'olay',
#   'kampanya',
#   'hattınızı',
#   'bize',
#   'geçiriyorsunuz',
#   'bizde',
#   'sizeeeee',
#   'dddddddddddddd'],
#  ['den',
#   'beri',
#   'türkcellliyim',
#   'ortalama',
#   'ay',
#   'liralık',
#   'kontör',
#   'harcamam',
#   'vardı',
#   'son',
#   'faturam',
#   'tl',
#   'fakat',
#   'cellocan',
#   'takkem',
#   'bile',
#   'yok'],
#  ['dogru',
#   'bilgiyi',
#   'alabilmek',
#   'icin',
#   'yapmam',
#   'lazim',
#   'illa',
#   'kavga',
#   'illa',
#   'siddet',
#   'off',
#   'turkcell',
#   'offf'],
#  ['hic',
#   'hic',
#   'begenmedim',
#   'account',
#   'kullaniyorum',
#   'neye',
#   'geldi',
#   'karisti',
#   'birbirine'],
#  ['ohaa', 'amk', 'tl', 'fatura', 'geldı', 'bana', 'ananın', 'amı', 'turkcell'],
#  ['sanane', 'istedigimi', 'derim', 'ben', 'sa', 'na'],
#  ['yine', 'birincil', 'dns', 'sunucusu', 'hatasi', 'verdi', 'baglanamiyorum'],
#  ['muzık',
#   'paketı',
#   'yapcaz',
#   'dıyıp',
#   'tlni',
#   'alıp',
#   'bırsey',
#   'yapmayan',
#   'turkcell',
#   'eskı',
#   'sevgılınızle',
#   'kankıymıs',
#   'kızlar',
#   'hanı',
#   'sovmek',
#   'ısterseniiz'],
#  ['ozaman',
#   'faturalarıda',
#   'paylaşalım',
#   'turkcellle',
#   'nede',
#   'olsa',
#   'hayat',
#   'paylaşınca',
#   'güzel'],
#  ['ocağımı', 'kuruttun'],
#  ['gün',
#   'önce',
#   'kontör',
#   'yükledim',
#   'turkcell',
#   'ogünden',
#   'beri',
#   'tane',
#   'mesaj',
#   'attı'],
#  ['kontor', 'yukle', 'kocan', 'olsun', 'turkcell', 'kanka', 'ahahahahahaha'],
#  ['saatte',
#   'baktım',
#   'beni',
#   'düşünüyor',
#   'dedim',
#   'anında',
#   'mesaj',
#   'geldi',
#   'turkcell',
#   'turkcell',
#   'peşimi',
#   'bırak',
#   'artık'],
#  ['kurumsalsaniz',
#   'almak',
#   'kadar',
#   'zor',
#   'seferinde',
#   'sabrimizi',
#   'zorlamasaniz'],
#  ['turkcell',
#   'iyice',
#   'sinirimi',
#   'bozmaya',
#   'basladi',
#   'kafasına',
#   'göre',
#   'paket',
#   'alıyor',
#   'yeniliyor'],
#  ['superonline', 'hayrına', 'aramaz', 'pek', 'bence', 'aç', 'yüzüne', 'kapat'],
#  ['zuzu', 'turkcell', 'gündür', 'mesaj', 'atmıyo', 'kesin', 'baska', 'var'],
#  ['git',
#   'allasen',
#   'yillarimi',
#   'turkcelle',
#   'verdim',
#   'birak',
#   'spayi',
#   'sipa',
#   'bile',
#   'vermediler'],
#  ['var',
#   'avea',
#   'bana',
#   'bugün',
#   'beleş',
#   'mb',
#   'internet',
#   'verdi',
#   'bunu',
#   'bana',
#   'turkcell',
#   'verebilir',
#   'mi',
#   'sorarım',
#   'büşra'],
#  ['dur',
#   'bi',
#   'mesaj',
#   'atalimda',
#   'sevgilisinden',
#   'geldi',
#   'sansin',
#   'turkcell'],
#  ['ödediğimiz',
#   'tel',
#   'faturalarının',
#   'i',
#   'kdv',
#   'i',
#   'öiv',
#   'devlet',
#   'turkcell',
#   'beraber',
#   'geçiriyor',
#   'anlayacağın'],
#  ['gündür',
#   'hattıma',
#   'tl',
#   'yüklemyiormuşum',
#   'ben',
#   'fakirim',
#   'turkcell',
#   'affet'],
#  ['reklam',
#   'icerikli',
#   'aramalari',
#   'istemiyorum',
#   'ozelliklede',
#   'pepsi',
#   'sigortalar',
#   'bankalar',
#   'engelleyemez',
#   'miyiz'],
#  ['küstüm',
#   'lan',
#   'turkcelle',
#   'ben',
#   'onun',
#   'mesajına',
#   'cevap',
#   'verdim',
#   'hatalısın',
#   'dio',
#   'oç',
#   'turkcell',
#   'küstüm',
#   'işteee'],
#  ['önce',
#   'in',
#   'beni',
#   'araması',
#   'gerkiyormuş',
#   'bunu',
#   'timde',
#   'söylediler',
#   'gülsem',
#   'mi',
#   'ağlasam',
#   'biçim',
#   'hizmet',
#   'anlayışı',
#   'ekimden',
#   'beri'],
#  ['bize',
#   'yazmadığı',
#   'bi',
#   'odunca',
#   'thank',
#   'youyu',
#   'bile',
#   'eksik',
#   'ediyo',
#   'telefonun',
#   'bipbipbip',
#   'bide',
#   'turkcell',
#   'heryerde',
#   'çeker',
#   'diyolar',
#   'alksjajn'],
#  ['yüzden', 'demek', 'isterdim', 'aynı', 'bkun', 'laciverti'],
#  ['bogazda',
#   'deniz',
#   'kenarinda',
#   'turkcell',
#   'in',
#   'cekmemesine',
#   'anlam',
#   'veremiyorum',
#   'yaa',
#   'nedir',
#   'buu'],
#  ['turkcell',
#   'benı',
#   'sesımden',
#   'tanır',
#   'turkcell',
#   'benı',
#   'sesımden',
#   'tanır',
#   'turkcell',
#   'benı',
#   'aasdfghjksasdfghj',
#   'yeteeer',
#   'beeeee',
#   'adamı',
#   'delırtırsın',
#   'turkcell'],
#  ['uykunun', 'guzel', 'yerinde', 'turkcellden', 'mesaj', 'gelmesi'],
#  ['günlük',
#   'superonline',
#   'deneyimim',
#   'sonucu',
#   'söyleyeyim',
#   'öyle',
#   'bişey',
#   'yok'],
#  ['sevgilimizsin'],
#  ['ilişkiler',
#   'karşılıklı',
#   'olmalı',
#   'hafta',
#   'süre',
#   'karşılık',
#   'almazsamsilerim',
#   'seni'],
#  ['superonline',
#   'baglattik',
#   'ilk',
#   'hiic',
#   'calismadi',
#   'arkadaslarimin',
#   'basina',
#   'geldi',
#   'iyice',
#   'arastir',
#   'abi'],
#  ['kımle', 'kadar', 'konusuyorsam', 'ay', 'turkcell', 'kıtlıyoooooor'],
#  ['internet',
#   'bağlantısında',
#   'sorun',
#   'yaşayan',
#   'ben',
#   'miyim',
#   'yoksa',
#   'yaygın',
#   'sorun',
#   'merak',
#   'ettim'],
#  ['mesaj',
#   'atsa',
#   'mesaj',
#   'sesi',
#   'şok',
#   'ifadesi',
#   'noooolur',
#   'olsun',
#   'sayın',
#   'abonemiz',
#   'amk',
#   'turkcell'],
#  ['telefonumu',
#   'gizli',
#   'numaradan',
#   'arayıp',
#   'hattınıza',
#   'geçmemi',
#   'teklif',
#   'etmenizden',
#   'tiksindim',
#   'geçeceğim',
#   'varsa',
#   'geçmem'],
#  ['turkcell',
#   'odenmemis',
#   'faturaniz',
#   'var',
#   'smslerini',
#   'erol',
#   'koseye',
#   'yazdiriyor',
#   'herhalde',
#   'full',
#   'caps',
#   'lock',
#   'acik',
#   'bisey',
#   'isteyince',
#   'mulayim',
#   'kucuk',
#   'harf'],
#  ['bunca',
#   'yıllık',
#   'turkcell',
#   'kullanıcısıyım',
#   'beni',
#   'bulmuyor',
#   'böyle',
#   'şeyler'],
#  ['günde',
#   'tane',
#   'sms',
#   'aldım',
#   'ngt',
#   'n',
#   'tanesi',
#   'turkcell',
#   'bilimum',
#   'giyim',
#   'mağazalarından',
#   'kimsenin',
#   'aramadığı',
#   'fin',
#   'hattımı',
#   'özlicem',
#   'nerdeyse'],
#  ['yilinin', 'iyi', 'reklam', 'yapan', 'gsm', 'operatoru', 'kullaniyorum'],
#  ['tesadufe',
#   'bak',
#   'ayrica',
#   'turkcell',
#   'internet',
#   'bi',
#   'gidiyor',
#   'bi',
#   'geliyor',
#   'sikayetim',
#   'var'],
#  ['baz', 'istasyonu', 'kuramadınız', 'ünlüler', 'deyince', 'kuruyonuz', 'amk'],
#  ['gündür',
#   'vodafone',
#   'internet',
#   'testleri',
#   'yapıyorum',
#   'turkcellin',
#   'g',
#   'sinyalinin',
#   'olmadığı',
#   'birçok',
#   'yerdeki',
#   'kalitesiyle',
#   'beni',
#   'adeta',
#   'şok',
#   'etti'],
#  ['mesaj', 'geldiyse', 'turkcelldir', 'arıyorsa', 'evdekilerdir'],
#  ['evet',
#   'hızlı',
#   'diğe',
#   'evimize',
#   'ulaştınız',
#   'mbit',
#   'in',
#   'ün',
#   'üzerine',
#   'çıktığını',
#   'göremedik'],
#  ['artık',
#   'yeter',
#   'çekmiyor',
#   'telefonum',
#   'sertab',
#   'ereneri',
#   'corluya',
#   'yollayın',
#   'bakalım',
#   'çeker',
#   'olacak'],
#  ['sms',
#   'paketi',
#   'alıp',
#   'ay',
#   'atmadığım',
#   'smslerin',
#   'parasını',
#   'ödemek',
#   'istemiyorum',
#   'internet',
#   'üzerinden'],
#  ['oha',
#   'internet',
#   'paketim',
#   'bitti',
#   'yeni',
#   'yapmistimm',
#   'oluyor',
#   'sana',
#   'turkcell'],
#  ['bi',
#   'umut',
#   'açıyorum',
#   'mesajlarını',
#   'yazıklar',
#   'olsun',
#   'sana',
#   'bana',
#   'turkcell'],
#  ['yarın', 'turkcelli', 'basalım', 'zamn'],
#  ['genc',
#   'paketimde',
#   'dk',
#   'görünmesine',
#   'rağmen',
#   'krediniz',
#   'yetersiz',
#   'uyarsıyla',
#   'karşılaşıyorum',
#   'müşteri',
#   'temsilcisiyle',
#   'görüşemiyorum'],
#  ['citysdeki',
#   'turkcell',
#   'tam',
#   'dolandırıcı',
#   'iphone',
#   'kontratli',
#   'fiyat',
#   'sordum',
#   'ten',
#   'başlıyor',
#   'dediler',
#   'yalan',
#   'yanlış',
#   'bilgi',
#   'veriyorlar'],
#  ['hayir'],
#  ['hangi', 'reklamı', 'guzeldiki', 'turkcellin'],
#  ['gündür',
#   'yazmayayım',
#   'şimdi',
#   'görürler',
#   'falan',
#   'dedim',
#   'artık',
#   'iş',
#   'işten',
#   'geçtiğine',
#   'göre',
#   'superonline',
#   'bana',
#   'adil',
#   'kullanım',
#   'şeyini',
#   'uygulamadı',
#   'gb'],
#  ['hahaha',
#   'malesef',
#   'ikiside',
#   'duruyo',
#   'panpa',
#   'turkcell',
#   'cepten',
#   'kopuyo',
#   'ttnet',
#   'pcden',
#   'turlu',
#   'kopuyoz'],
#  ['hemde',
#   'severek',
#   'ağzındanburnundan',
#   'tükürükler',
#   'çıkan',
#   'avukat',
#   'birlikte',
#   'ee',
#   'nede',
#   'olsa',
#   'hayat',
#   'paylaşınca',
#   'güzel'],
#  ['kimse', 'turkcell', 'degil', 'bari', 'avea', 'geceyim'],
#  ['beni',
#   'arkadaşlarımın',
#   'ilgisizliği',
#   'değil',
#   'turkcell',
#   'vakıfbankın',
#   'zamansız',
#   'ilgisi',
#   'bitirdi'],
#  ['değilde',
#   'turkcell',
#   'reklamindaki',
#   'ağlak',
#   'yandan',
#   'düdüklü',
#   'sesi',
#   'olan',
#   'adam',
#   'abi',
#   'benim',
#   'yerime',
#   'bulsun',
#   'tibete',
#   'götürüp',
#   'orada',
#   'biraksin'],
#  ['çüşşşşşşş',
#   'turkcel',
#   'sms',
#   'paketını',
#   'tl',
#   'yapmısssssss',
#   'ohaaaa',
#   'yanı',
#   'napmaya',
#   'calısıyosun',
#   'sen',
#   'turkcelll'],
#  ['yede',
#   'bişey',
#   'kalmadı',
#   'hala',
#   'yagmur',
#   'yagdıgında',
#   'internet',
#   'gidiyor',
#   'sana',
#   'sesleniyorum'],
#  ['internet',
#   'hizinda',
#   'ttneti',
#   'arattigin',
#   'icin',
#   'cok',
#   'tesekkur',
#   'ederim',
#   'turkcell'],
#  ['olm',
#   'tl',
#   'ye',
#   'sms',
#   'paketimi',
#   'olur',
#   'allah',
#   'belani',
#   'versin',
#   'turkcell'],
#  ['türkcell',
#   'hizmetlerini',
#   'arıyorummesaj',
#   'bırakıyorum',
#   'nedense',
#   'türlü',
#   'geri',
#   'dönmüyorlarturkcellduyurulur'],
#  ['ara',
#   'kimse',
#   'beni',
#   'arayip',
#   'sormuyo',
#   'turkcell',
#   'mesaj',
#   'attiginda',
#   'sevinicek',
#   'hale',
#   'geldim',
#   'sevgili',
#   'arkadaslarima',
#   'duyurulur'],
#  ['bundan', 'sonrasını', 'düşünsün', 'gayet', 'memnunuz', 'vodofondan'],
#  ['kusurlu',
#   'hizmet',
#   'veriyosun',
#   'ben',
#   'seni',
#   'kadar',
#   'severken',
#   'yapma',
#   'bana',
#   'bunuu'],
#  ['kazanmayalim',
#   'yapilan',
#   'bitmesine',
#   'ramak',
#   'kala',
#   'duyurulan',
#   'kampanya',
#   'herseyi',
#   'sms',
#   'atarken',
#   'buna',
#   'dair',
#   'sifir',
#   'sms'],
#  ['sagol',
#   'turkcell',
#   'sen',
#   'uyarmasan',
#   'cekilisle',
#   'bmw',
#   'kazandigima',
#   'inanacaktim'],
#  ['ayda',
#   'tl',
#   'verdigim',
#   'paketten',
#   'googlea',
#   'dahi',
#   'giremiyorum',
#   'tum',
#   'yetkililerinize',
#   'selam',
#   'olsun'],
#  ['bı',
#   'ıpad',
#   'işini',
#   'halledemeyen',
#   'turkcell',
#   'platinum',
#   'uyesı',
#   'cinnet',
#   'geçirerek',
#   'saçlarını',
#   'yoldu'],
#  ['arayin',
#   'dedi',
#   'tam',
#   'saat',
#   'dk',
#   'çağrı',
#   'merkezindeki',
#   'arkadaş',
#   'konuştum',
#   'bana',
#   'kontör',
#   'transferlerinin',
#   'ücretlendirildiği',
#   'söylendi'],
#  ['ödemeli',
#   'aramlari',
#   'cevaplayip',
#   'haberiniz',
#   'olmadan',
#   'odediginiz',
#   'krş',
#   'larin',
#   'talep',
#   'ettiginizde',
#   'geri',
#   'odenecegini',
#   'biliyor',
#   'muydunuz',
#   'bilin'],
#  ['dakikadır', 'durumda', 'bekliyor', 'turkcell', 'g', 'sıçmış', 'durumda'],
#  ['cok',
#   'pahalisiniz',
#   'dakikali',
#   'bol',
#   'internetli',
#   'uygun',
#   'fiyatli',
#   'paket',
#   'istiyoruz',
#   'mesela',
#   'gb',
#   'internetdk',
#   'tl'],
#  ['internet',
#   'paketimin',
#   'bytelari',
#   'yerinde',
#   'sayıyor',
#   'insallah',
#   'turkcell',
#   'sonunda',
#   'öpmez',
#   'beni'],
#  ['ondan',
#   'mesaj',
#   'beklersin',
#   'onun',
#   'yerine',
#   'turkcell',
#   'mesaj',
#   'atar',
#   'iste',
#   'cok',
#   'acı'],
#  ['turkcelldeki',
#   'kadinin',
#   'turk',
#   'aksaniyla',
#   'ingiliz',
#   'ingilizcesi',
#   'konusma',
#   'cabasina',
#   'hastayim',
#   'british',
#   'senin',
#   'neyine',
#   'kardej'],
#  ['adamı',
#   'memnun',
#   'etmek',
#   'kolay',
#   'değil',
#   'biliyorum',
#   'bizim',
#   'yaşamkentteki',
#   'baz',
#   'istasyonlarını',
#   'bi',
#   'halletseniz',
#   'şık',
#   'olmaz'],
#  ['müşterilerinizi', 'cekim', 'gücünüz', 'kaybedeceksiniz'],
#  ['yalancıların', 'reklam', 'panosu', 'gibisin'],
#  ['ttneti',
#   'bilmiyorum',
#   'superonlinenin',
#   'servis',
#   'hizmeti',
#   'cok',
#   'cok',
#   'kotuuu'],
#  ['paylasmak',
#   'guzel',
#   'onunla',
#   'paylasiyrz',
#   'bizimle',
#   'cihazlari',
#   'paylassa',
#   'sloganin',
#   'hakkini',
#   'verse',
#   'turkcell'],
#  ['sosyal',
#   'medya',
#   'faciası',
#   'facebook',
#   'sayfasında',
#   'yaşanıyor',
#   'ah',
#   'ergenleri',
#   'başına',
#   'oturtmaktan',
#   'anlarsınız',
#   'sevgili',
#   'ajanslar'],
#  ['timelineda',
#   'bilgi',
#   'kirliligi',
#   'sabahki',
#   'cakma',
#   'pozitif',
#   'tonla',
#   'gunaydin',
#   'esdeger'],
#  ['türkcelle',
#   'gökhan',
#   'özen',
#   'sarkısı',
#   'türkcell',
#   'sen',
#   'bensiz',
#   'el',
#   'ocağında',
#   'ağlayacaksın'],
#  ['sabah',
#   'emailla',
#   'gelen',
#   'turkcell',
#   'faturası',
#   'sonucunda',
#   'anladım',
#   'hayat',
#   'geçirince',
#   'güzel',
#   'aaaaaooooo',
#   'roaming',
#   'yapana',
#   'pis',
#   'kayınca',
#   'güzel',
#   'lalalalalala'],
#  ['dsmart',
#   'bugünler',
#   'ex',
#   'aşkım',
#   'turkcellden',
#   'bile',
#   'fazla',
#   'mesaj',
#   'göndermeye',
#   'başladıçok',
#   'seviyor',
#   'olmaı'],
#  ['iptal',
#   'etmek',
#   'istersem',
#   'taahhüdüm',
#   'başlamadan',
#   'evvel',
#   'kampanya',
#   'fiyatlarını',
#   'dahil',
#   'ederek',
#   'küsur',
#   'lira',
#   'bedel',
#   'çıkartıyor',
#   'çakal'],
#  ['orospusun',
#   'turkcell',
#   'biliyosun',
#   'paketimin',
#   'bittiğini',
#   'inadına',
#   'mesaj',
#   'atıyosun',
#   'dd'],
#  ['bide', 'heryerde', 'çeker', 'diyorlar'],
#  ['değilde', 'turkcell', 'ay', 'dakikamın', 'üstüne', 'yattı', 'sanırım'],
#  ['kamil',
#   'koç',
#   'bi',
#   'kampanya',
#   'yapmış',
#   'aç',
#   'turkcell',
#   'beraber',
#   'tam',
#   'saçmalıkvay',
#   'efenim',
#   'yüzde',
#   'koltukta',
#   'geçerliyolkartsız',
#   'kullanılamıyo'],
#  ['bugún', 'turkcell', 'mesaj', 'atmadı', 'kesın', 'başka', 'var'],
#  ['turkcell', 'pahalı', 'demek', 'istiyorsun'],
#  ['internet', 'paketim', 'var', 'turkcel', 'hala', 'kontor', 'alio', 'benden'],
#  ['turkcellde',
#   'iyice',
#   'uçtu',
#   'amk',
#   'yok',
#   'yükle',
#   'al',
#   'yükle',
#   'al',
#   'hesaplamalarıma',
#   'göre',
#   'bin',
#   'tl',
#   'yüklesem',
#   'şirketi',
#   'üstüme',
#   'yapacaklar'],
#  ['oha',
#   'amk',
#   'arkadaşla',
#   'dk',
#   'konuştuk',
#   'tl',
#   'kurus',
#   'gitmiş',
#   'resmen',
#   'soyuldum',
#   'türkcell',
#   'tarafından'],
#  ['fırça', 'attım', 'akşam', 'akşam', 'rahatladım'],
#  ['saat', 'bekle', 'offff'],
#  ['hayır', 'yaaa', 'turkcell', 'gayet'],
#  ['tl',
#   'mi',
#   'tl',
#   'yapma',
#   'türkcell',
#   'sus',
#   'bi',
#   'mınakodum',
#   'sus',
#   'saat',
#   'başı',
#   'mesaj',
#   'atılır'],
#  ['kanka',
#   'turkcelli',
#   'kazıkladım',
#   'lan',
#   'sms',
#   'yaptım',
#   'seneye',
#   'bitiyo',
#   'allah',
#   'belanı',
#   'versin'],
#  ['kampanya',
#   'smslerinden',
#   'başka',
#   'iletişim',
#   'kuramayan',
#   'ödül',
#   'almış',
#   'herkes',
#   'birbirini',
#   'ağırlamış',
#   'hayat',
#   'faydasızca',
#   'güzel'],
#  ['paylaştıkça',
#   'çoğalan',
#   'sevgine',
#   'sokim',
#   'be',
#   'turkcell',
#   'adam',
#   'rakı',
#   'içmelik',
#   'reklam',
#   'müziği',
#   'yaparmı',
#   'be'],
#  ['hatta',
#   'turkcell',
#   'atesle',
#   'oynuyor',
#   'kendileri',
#   'donmezse',
#   'hatadan',
#   'buyutecem',
#   'isi'],
#  ['verilen',
#   'sure',
#   'icinde',
#   'belgelerinizi',
#   'tamamlamadiginiz',
#   'icin',
#   'hattiniz',
#   'aramalara',
#   'kapatilmistir',
#   'diyen',
#   'koca',
#   'bi',
#   'alkış',
#   'istiyorum'],
#  ['kampanyaları',
#   'içerisndeki',
#   'süpriz',
#   'fatura',
#   'den',
#   'olarak',
#   'değerlendiriyorum',
#   'konudan',
#   'müzdarip',
#   'varmı'],
#  ['benim', 'turkcell', 'bugün', 'fena', 'dağıttıdeneme', 'tweetidir'],
#  ['turkcell',
#   'kafayi',
#   'yemis',
#   'gun',
#   'sonra',
#   'bitecek',
#   'olan',
#   'paketim',
#   'icin',
#   'simdiden',
#   'mesaj',
#   'atiyorsun',
#   'kardesim'],
#  ['eee',
#   'demişler',
#   'etme',
#   'çoluk',
#   'çocukla',
#   'muhabbet',
#   'küstürürsün',
#   'silme',
#   'le',
#   'götünü',
#   'kestirirsin'],
#  ['selam',
#   'canım',
#   'evde',
#   'internetim',
#   'berbat',
#   'superonline',
#   'iyi',
#   'bunu',
#   'seçtim',
#   'saolsun',
#   'oda',
#   'attı',
#   'kazzığını',
#   'nasılsın'],
#  ['senedir',
#   'kullandığım',
#   'faturalı',
#   'hattımı',
#   'eksik',
#   'belge',
#   'yüzünden',
#   'yılbaşı',
#   'öncesi',
#   'aramalara',
#   'kapatan',
#   'ey',
#   'vefasız',
#   'turkcell'],
#  ['offf',
#   'turkcell',
#   'daralttin',
#   'beni',
#   'hergün',
#   'mesajtamam',
#   'anladık',
#   'tanımadığımız',
#   'numaralardan',
#   'gelen',
#   'ödül',
#   'kazandınız',
#   'mesajarina',
#   'itibar',
#   'etmiycez'],
#  ['sesim',
#   'kısıldıı',
#   'içn',
#   'turkcell',
#   'beni',
#   'sesimden',
#   'tanıyamadı',
#   'waaow',
#   'demek',
#   'gerçekten',
#   'güwenli',
#   'ben',
#   'işimi',
#   'nası',
#   'halletcem'],
#  ['ay', 'turkcell', 'sağlam', 'internet', 'faturası', 'öder', 'herhalde'],
#  ['edge',
#   'g',
#   'arasinda',
#   'hiz',
#   'bakimindan',
#   'hic',
#   'fark',
#   'yokinternet',
#   'paketimden',
#   'mi',
#   'kaynakli'],
#  ['turkcell',
#   'numaramı',
#   'taşıdığım',
#   'benim',
#   'hatırımı',
#   'sordu',
#   'tl',
#   'kadar',
#   'aynı',
#   'gun',
#   'internet',
#   'tamamı'],
#  ['seviyorsan',
#   'gel',
#   'konussurekli',
#   'mesaj',
#   'atıp',
#   'durma',
#   'abaza',
#   'mısın',
#   'nesin'],
#  ['götürdüler',
#   'aldıkları',
#   'turkcel',
#   'bayiine',
#   'program',
#   'çökmüş',
#   'içinde',
#   'demişler',
#   'geri',
#   'gönderdiler',
#   'tel'],
#  ['öl', 'turkcell', 'öl'],
#  ['benden',
#   'ay',
#   'tl',
#   'değil',
#   'tl',
#   'alman',
#   'gerekiyordu',
#   'keksin',
#   'turkcell'],
#  ['reklamlarında',
#   'dağda',
#   'bayırda',
#   'çekiyor',
#   'fakat',
#   'istanbulun',
#   'göbeğinde',
#   'bizim',
#   'evde',
#   'çekmiyordu'],
#  ['arkadaşımın',
#   'telefonunda',
#   'sevgilisinin',
#   'adını',
#   'turkcell',
#   'değiştirdim',
#   'gelen',
#   'msjları',
#   'okumadan',
#   'siliyor',
#   'ayrıldı'],
#  ['operatörler',
#   'internet',
#   'paketlerini',
#   'ücretlendirme',
#   'konusunda',
#   'acımasız'],
#  ['kanyon',
#   'turkcell',
#   'derki',
#   'turkcell',
#   'müşteri',
#   'hizmetleri',
#   'yetkili',
#   'değil',
#   'onlar',
#   'size',
#   'soylemiş',
#   'olabilir',
#   'gecersiz'],
#  ['sms', 'altyapin', 'mi', 'pırtladi', 'ulen', 'turkcell', 'kılım', 'sana'],
#  ['baz',
#   'istasyonu',
#   'monte',
#   'ederim',
#   'sana',
#   'turkcell',
#   'açılacakk',
#   'arkadaşş'],
#  ['ölmeden',
#   'önce',
#   'söylenen',
#   'son',
#   'sözler',
#   'calisilan',
#   'sirket',
#   'turkcellsayın',
#   'patron',
#   'arkadaşlarla',
#   'birlikte',
#   'topluca',
#   'vodafonea',
#   'geçiyoruz',
#   'toplu',
#   'katliam'],
#  ['ilginç',
#   'olan',
#   'telefonlar',
#   'geliyor',
#   'ardından',
#   'turkcell',
#   'emniyetten',
#   'mesaj',
#   'geliyor',
#   'itibar',
#   'etmeyin'],
#  ['sana',
#   'katılıyorum',
#   'hizmet',
#   'kalitesine',
#   'önem',
#   'verdigini',
#   'düşünen',
#   'iste'],
#  ['çözüm',
#   'merkezi',
#   'lütfen',
#   'duyun',
#   'sesimi',
#   'beni',
#   'arayıp',
#   'sorunumu',
#   'çözün',
#   'artık',
#   'saat',
#   'olcak'],
#  ['tl', 'ödemeyi', 'yapacağım', 'süperonline', 'içime', 'oturur'],
#  ['kadinlar', 'turkcell', 'gibidir', 'once', 'vaad', 'eder', 'sonra', 'çakar'],
#  ['burdan',
#   'gsm',
#   'operatörlerine',
#   'sesleniyorum',
#   'sen',
#   'turkcell',
#   'sen',
#   'vodafone',
#   'sende',
#   'avea',
#   'vapurda',
#   'artik',
#   'telefonlar',
#   'çeksin',
#   'you',
#   'can',
#   'easily',
#   'realize'],
#  ['reklam',
#   'filmlerindeki',
#   'dış',
#   'sesin',
#   'son',
#   'yıllarda',
#   'tonlamasında',
#   'konuştuğunu',
#   'kasımpaşalı',
#   'stayla',
#   'fark',
#   'eden',
#   'ben',
#   'değilim'],
#  ['turksel',
#   'sadece',
#   'bizi',
#   'aldatsa',
#   'gene',
#   'iyi',
#   'kaç',
#   'milyon',
#   'abonen',
#   'aman',
#   'sevgilin',
#   'var',
#   'canim'],
#  ['afedersin', 'turkcell', 'cok', 'kazik'],
#  ['iyiki',
#   'bi',
#   'tl',
#   'yükledik',
#   'turkcell',
#   'sabahtan',
#   'beri',
#   'atmadığın',
#   'kampanya',
#   'kalmadı'],
#  ['lira', 'tel', 'faturasi', 'mi', 'olur', 'turkcell'],
#  ['sn',
#   'turkcell',
#   'eski',
#   'müşteri',
#   'olarak',
#   'ay',
#   'bana',
#   'güzel',
#   'geçiriyosunuz',
#   'geçen',
#   'ay',
#   'ytl',
#   'ödedim',
#   'ay',
#   'fatura',
#   'yollamışız'],
#  ['sabah',
#   'sabah',
#   'turkcell',
#   'musteri',
#   'hizmetleri',
#   'omrumuzu',
#   'resmen',
#   'kit',
#   'insanlar',
#   'varmis'],
#  ['ay',
#   'boyunca',
#   'haftanın',
#   'gunu',
#   'diyor',
#   'konus',
#   'diyor',
#   'bağıra',
#   'bağıra',
#   'saat',
#   'yazısını',
#   'ekranda',
#   'gösterio',
#   'söylemiyor',
#   'uyanik',
#   'turkcell'],
#  ['ohaaaaaaaaaaa',
#   'tl',
#   'cep',
#   'telefonu',
#   'faturasımı',
#   'olur',
#   'beeeeee',
#   'sıçtın',
#   'yine',
#   'ağzıma',
#   'turkcell'],
#  ['turkcell',
#   'den',
#   'artık',
#   'kadar',
#   'paraya',
#   'saate',
#   'kadar',
#   'kadar',
#   'konuş',
#   'sms',
#   'leri',
#   'gelsin',
#   'istemiyorum'],
#  ['arada',
#   'omurilik',
#   'felçlilerine',
#   'gönderilen',
#   'sms',
#   'den',
#   'sms',
#   'bedel',
#   'kesmek',
#   'nedir'],
#  ['ömrümü', 'yiyen', 'şeyden', 'turkcell'],
#  ['kontör',
#   'yüklediğim',
#   'anda',
#   'bitiyo',
#   'sikicem',
#   'ha',
#   'napıyo',
#   'turkcell'],
#  ['kullanmadığım',
#   'bisin',
#   'parasını',
#   'alan',
#   'turkcell',
#   'senin',
#   'taaaa',
#   'mınakoyim'],
#  ['kodumun', 'turkcelli', 'geçen', 'ayın', 'faturasını', 'yeni', 'yolluyo'],
#  ['murpa',
#   'cay',
#   'reklamindan',
#   'sonra',
#   'psikolog',
#   'destegi',
#   'almaya',
#   'karar',
#   'verdim',
#   'once',
#   'turkcell',
#   'sonra',
#   'bakalim',
#   'neler',
#   'cikicak'],
#  ['senden', 'degil', 'iphone', 'patates', 'almam', 'artik'],
#  ['lanet', 'olsun', 'turkcel'],
#  ['dudullunun',
#   'gobeginde',
#   'edge',
#   'baglaniyor',
#   'ceksin',
#   'daga',
#   'mi',
#   'cikmamiz',
#   'lazim',
#   'anlamadim'],
#  ['ekip',
#   'yollamishizima',
#   'carrima',
#   'curruma',
#   'bakiyoryaptigi',
#   'ilk',
#   'sey',
#   'hiz',
#   'testi',
#   'yapilan',
#   'web',
#   'sitelerio',
#   'site',
#   'sonuclarini',
#   'kabuletmem',
#   'dedim'],
#  ['konturum',
#   'olmadiginda',
#   'turkcell',
#   'in',
#   'bana',
#   'msg',
#   'atmasi',
#   'bile',
#   'insani',
#   'uzuyo',
#   'lantl',
#   'yuklede',
#   'bizde',
#   'kurtulalim',
#   'gunde'],
#  ['kontör', 'yükleyince', 'yalakalik', 'yapan', 'turkcell', 'insanlar', 'var'],
#  ['bugün',
#   'turkcellden',
#   'mesaj',
#   'gelmeyince',
#   'musteri',
#   'hizmetlerini',
#   'arayıp',
#   'hmm',
#   'neyse',
#   'sen',
#   'mesgulsun',
#   'galiba',
#   'bye',
#   'deyip',
#   'kapattım'],
#  ['iphone',
#   's',
#   's',
#   'uygulamasi',
#   'seven',
#   'sevilir',
#   'yakinda',
#   'butun',
#   'turkcelllerde'],
#  ['bugün', 'tam', 'arayan', 'superonline', 'derdin', 'anlayabilsem'],
#  ['merhaba',
#   'sizden',
#   'cevaplayip',
#   'e',
#   'bastiginiz',
#   'ödemeli',
#   'arama',
#   'krş',
#   'ücret',
#   'aldigini',
#   'biliyor',
#   'muydunuz',
#   'artik',
#   'biliyorsunuz'],
#  ['konserden',
#   'sonra',
#   'turkcellin',
#   'sayfasında',
#   'direk',
#   'bitti',
#   'rüya',
#   'çalması',
#   'turkcellin',
#   'hayatın',
#   'bize',
#   'anca',
#   'rüyanızda',
#   'görürsünüz',
#   'deme',
#   'tarzıdır'],
#  ['turkcell', 'mal', 'amk', 'mal'],
#  ['bana',
#   'turkcellin',
#   'sevgi',
#   'sözcüklerinden',
#   'yollasa',
#   'ıy',
#   'kro',
#   'derim',
#   'toprağım',
#   'nedir',
#   'kusura',
#   'bakma',
#   'turkcell',
#   'romantik',
#   'değilsin'],
#  ['fiber',
#   'internet',
#   'in',
#   'adil',
#   'kullanım',
#   'haksızlığına',
#   'sessiz',
#   'kalmayın',
#   'emsal',
#   'karar',
#   'çıktı',
#   'rt'],
#  ['kanka',
#   'ben',
#   'vodafone',
#   'geçicem',
#   'turkcell',
#   'cok',
#   'kazık',
#   'gel',
#   'beraber',
#   'geceliim'],
#  ['yaparsam', 'yapayım', 'turkcellin', 'bana', 'yine', 'geçirmesine'],
#  ['gün',
#   'turkcell',
#   'şöyle',
#   'msj',
#   'atıcak',
#   'kadar',
#   'msj',
#   'attım',
#   'cevap',
#   'vermiyorsun'],
#  ['ben',
#   'eski',
#   'seviyorum',
#   'ulaşmak',
#   'önce',
#   'kurumsal',
#   'aşmak',
#   'gerekiyor'],
#  ['sen',
#   'kadar',
#   'salak',
#   'operatörsün',
#   'turkcell',
#   'gecenin',
#   'inde',
#   'aynı',
#   'mesaj',
#   'kere',
#   'üst',
#   'üste',
#   'gönderilir',
#   'mi',
#   'uyuyorsam',
#   'erken',
#   'kalkacaksam'],
#  ['zaman',
#   'tweeter',
#   'yada',
#   'facebooka',
#   'girsem',
#   'benim',
#   'turkcell',
#   'g',
#   'ye',
#   'geçiyoralacam',
#   'ayagımın',
#   'altına'],
#  ['turkcell',
#   'cok',
#   'ucmus',
#   'avea',
#   'kazanir',
#   'sonraki',
#   'iphone',
#   'aveadan',
#   'gelecek',
#   'belli',
#   'oldu'],
#  ['adinda',
#   'telefon',
#   'operatoru',
#   'vardeli',
#   'dumrul',
#   'dan',
#   'besbin',
#   'beterpara',
#   'carpmanin',
#   'adi',
#   'olmuseline',
#   'ver',
#   'kolunu',
#   'kurtaramiyorsun'],
#  ['bütün',
#   'arkadaşlarım',
#   'aveaya',
#   'geçiyorbeğendin',
#   'mi',
#   'yaptığını',
#   'turkcell',
#   'he',
#   'beğendin',
#   'mi',
#   'geçmeyin',
#   'yıa'],
#  ['numarasını',
#   'turkcelle',
#   'taşıyana',
#   'dk',
#   'yöne',
#   'zaten',
#   'yıllardır',
#   'turkcelli',
#   'olanlar',
#   'sürünsün',
#   'onlar',
#   'para',
#   'basıyo',
#   'dimi',
#   'tabi'],
#  ['salak',
#   'blackberry',
#   'paketi',
#   'güncellemiyor',
#   'he',
#   'turkcell',
#   'güncellemiyor'],
#  ['noktada',
#   'sinyal',
#   'gucundeki',
#   'azalmayi',
#   'geri',
#   'bildirim',
#   'yaptiktan',
#   'gun',
#   'sonra',
#   'aranip',
#   'ayni',
#   'noktadamisiniz',
#   'aranmak',
#   'komik'],
#  ['limitsiz',
#   'internet',
#   'satılan',
#   'tarifenin',
#   'gb',
#   'kotalı',
#   'olması',
#   'saçma',
#   'teşekkürler',
#   'superonline'],
#  ['avea', 'bile', 'acikladi', 'herturlu', 'fiyat', 'dan', 'tik', 'yok'],
#  ['ön',
#   'ödemede',
#   'değil',
#   'cekim',
#   'gücünde',
#   'sorun',
#   'hayat',
#   'cam',
#   'kenarında',
#   'telefonla',
#   'konuşurken',
#   'guzel'],
#  ['turkcell', 'çözüm', 'ürettimi'],
#  ['yine',
#   'bütün',
#   'timlerin',
#   'yepyeni',
#   'tabelaları',
#   'değişiyor',
#   'israf',
#   'vergiden',
#   'mi',
#   'düşüyorsunuz',
#   'napıyorsunuz',
#   'anlamadım'],
#  ['kanka',
#   'turkcelli',
#   'kazıkladım',
#   'lan',
#   'sms',
#   'yaptım',
#   'seneye',
#   'bitiyo',
#   'allah',
#   'belanı',
#   'versin'],
#  ['cihaz',
#   'kaydini',
#   'saatte',
#   'yaparak',
#   'cumle',
#   'bekleyenleri',
#   'cileden',
#   'cikaran',
#   'kanyon',
#   'yilin',
#   'musteri',
#   'hizmetleri',
#   'merkezi',
#   'ilan',
#   'ediyrm'],
#  ['turkcell', 'hizmet', 'ekibi', 'kadar', 'yavaş', 'çalışıyor', 'öyle'],
#  ['ohhh',
#   'ayki',
#   'tel',
#   'fatura',
#   'paramı',
#   'tamirci',
#   'senden',
#   'önce',
#   'kaptı',
#   'turkcell'],
#  ['turkcell',
#   'den',
#   'alicam',
#   'ariycaklardi',
#   'sozde',
#   'hala',
#   'aramadilar',
#   'amuhagoyim'],
#  ['turkcell',
#   'in',
#   'sundugu',
#   'hizmet',
#   'ancak',
#   'karekter',
#   'hata',
#   'sorunu',
#   'vardi',
#   'umarim',
#   'duzeltmislerdir'],
#  ['tcell', 'uç', 'kaaat'],
#  ['telefonumun',
#   'bozulması',
#   'sonrasında',
#   'turkcellden',
#   'gelen',
#   'yedek',
#   'telefonda',
#   'bozuk',
#   'çıktı',
#   'an'],
#  ['turkcel', 'sen', 'personelinin', 'ak'],
#  ['onların',
#   'bulamadığı',
#   'çözümü',
#   'bulduk',
#   'ailece',
#   'hat',
#   'vodafonea',
#   'geçtik',
#   'sorun',
#   'kökten',
#   'çözüldü'],
#  ['değil',
#   'turkcellcim',
#   'sana',
#   'teşekkür',
#   'ediyorum',
#   'tvitimdebinküsür',
#   'dk',
#   'varmış',
#   'benim',
#   'sadece',
#   'trkcll',
#   'konuşabileceğimniye',
#   'yöne',
#   'değil'],
#  ['turkcell',
#   'in',
#   'faturalandırma',
#   'sistemi',
#   'kime',
#   'tutturursan',
#   'sistemi'],
#  ['le',
#   'ilişkimiz',
#   'tek',
#   'taraflı',
#   'diyor',
#   'bizimle',
#   'bişeyini',
#   'paylaşmıyor',
#   'bizden',
#   'bekliyor'],
#  ['hayat',
#   'paylaşınca',
#   'güzel',
#   'iğrençliğinin',
#   'yanında',
#   'oskar',
#   'alır',
#   'fasulye',
#   'reklamı'],
#  ['şikayet',
#   'kaydı',
#   'açtırıyorum',
#   'saat',
#   'arayan',
#   'arkadaş',
#   'saniyede',
#   'işlemimi',
#   'yapıyoryine',
#   'aynı',
#   'oldu',
#   'saat'],
#  ['sabahtan', 'beri', 'beni', 'arıyorsunne', 'istiyorsun'],
#  ['degilde',
#   'turkcell',
#   'nasil',
#   'sayfasini',
#   'yurt',
#   'disindakilere',
#   'kilitlemis',
#   'ona',
#   'yaniyorum'],
#  ['bloguma',
#   'istanbuldan',
#   'yorum',
#   'bırakan',
#   'superonline',
#   'müşterisi',
#   'git',
#   'kendinle',
#   'kafa',
#   'bul',
#   'tabi',
#   'bulman',
#   'kafa',
#   'lazım',
#   'neyse'],
#  ['turkcellin',
#   'ta',
#   'bi',
#   'kontör',
#   'yükledik',
#   'saat',
#   'oldu',
#   'gelmedi',
#   'iş'],
#  ['seni', 'sevmiyoruumm'],
#  ['oc',
#   'turkcell',
#   'senedır',
#   'bana',
#   'evde',
#   'vınn',
#   'kullandırıyosun',
#   'ınsallah',
#   'batarsın'],
#  ['kadar',
#   'operator',
#   'degistirdim',
#   'turkcell',
#   'kadar',
#   'kazik',
#   'atanini',
#   'gormedim',
#   'arkadas',
#   'smsim',
#   'bitmemis',
#   'smsin',
#   'btti',
#   'diyip',
#   'hattimdan',
#   'tl',
#   'yi',
#   'aldi',
#   'esekler'],
#  ['offf',
#   'diyorum',
#   'sabah',
#   'kvk',
#   'musteri',
#   'temsilcisi',
#   'sonra',
#   'turkcell',
#   'ardindan',
#   'isbankasi',
#   'devamli',
#   'bant',
#   'e',
#   'bas',
#   'e',
#   'bas',
#   'insanla',
#   'konusmak',
#   'istiyorum',
#   'ulennnn'],
#  ['kotanda',
#   'mbın',
#   'kalması',
#   'nedir',
#   'bilir',
#   'misin',
#   'insafsızadi',
#   'türkcell'],
#  ['bazen',
#   'kadar',
#   'uyuzsunuz',
#   'başka',
#   'operatörün',
#   'kapısından',
#   'dönüyorum',
#   'harbi',
#   'kaldı',
#   'internet',
#   'paketi',
#   'ilimi',
#   'kuruttunuz'],
#  ['turkcell'],
#  ['düzenli',
#   'ilişki',
#   'dediğimizde',
#   'hepimizin',
#   'aklına',
#   'turkcell',
#   'gelmiyor',
#   'sahiden'],
#  ['tane', 'acik', 'turkcell', 'ykmu', 'amk'],
#  ['hani',
#   'turkcell',
#   'cekerdi',
#   'bi',
#   'konusmam',
#   'tam',
#   'kesildi',
#   'umarim',
#   'reklamlarda',
#   'bunu',
#   'islerler'],
#  ['sen',
#   'zaman',
#   'milleti',
#   'aptal',
#   'degilde',
#   'abdal',
#   'yerine',
#   'koyacaksin'],
#  ['in',
#   'hayat',
#   'paylasinca',
#   'guzel',
#   'reklami',
#   'emotional',
#   'selling',
#   'olayini',
#   'fazla',
#   'abartmisbilincaltina',
#   'calismasi',
#   'gerekirkenkor',
#   'goze',
#   'parmak',
#   'sokms'],
#  ['varya', 'allahtan', 'durexte', 'falan', 'çalışmıyosun'],
#  ['icim', 'dişim', 'turkcell', 'oldu', 'kubat', 'yeter'],
#  ['internet',
#   'basvurusu',
#   'yaparken',
#   'adil',
#   'kullanim',
#   'koşullarını',
#   'bildirmeyip',
#   'kota',
#   'dolumunda',
#   'mail',
#   'atan',
#   'superonline',
#   'tebrikler'],
#  ['faturalı',
#   'hattı',
#   'kontrlye',
#   'çevrdm',
#   'son',
#   'extre',
#   'dn',
#   'ay',
#   'sonra',
#   'fatura',
#   'gldi',
#   'onuda',
#   'ödediğim',
#   'halde',
#   'yine',
#   'fatura',
#   'geldi',
#   'kapitalizmturkcelll'],
#  ['sevgilimi',
#   'turkcell',
#   'kaydettim',
#   'kimse',
#   'gelen',
#   'mesajlara',
#   'bakmıyo',
#   'artık',
#   'aklınızda',
#   'bulunsun'],
#  ['e',
#   'veren',
#   'turkcell',
#   'kampanyasının',
#   'yüzünün',
#   'serdar',
#   'ortaç',
#   'olması',
#   'şaşırtıcı',
#   'gelmedi',
#   'nedense'],
#  ['türksel',
#   'millete',
#   'hediye',
#   'tl',
#   'veriyo',
#   'benden',
#   'hediye',
#   'tl',
#   'çalıyo',
#   'nebe',
#   'tl',
#   'lerim',
#   'konusmadan',
#   'bitiyo'],
#  ['iyi',
#   'olmuş',
#   'yalaka',
#   'acuna',
#   'kıl',
#   'oluyordum',
#   'batsın',
#   'sürünsün',
#   'turkcelle',
#   'fatura',
#   'olarak',
#   'ödediğimiz',
#   'paraları',
#   'cebe',
#   'indiriyormuş',
#   'şerefsiz'],
#  ['kısa',
#   'mesaj',
#   'yoluyla',
#   'taciz',
#   'etmek',
#   'suçtur',
#   'istemiyorum',
#   'artık',
#   'buna',
#   'son',
#   'ver'],
#  ['paramızla',
#   'rezil',
#   'oluyoruz',
#   'saçma',
#   'sebeple',
#   'hat',
#   'kapatan',
#   'turkcell',
#   'neyin',
#   'kafasını',
#   'yaşıyorsun'],
#  ['turkcell', 'fiyat', 'çekecekseniz', 'getirmeyin'],
#  ['birakin',
#   'su',
#   'kampanya',
#   'ayaklarini',
#   'gnizi',
#   'istanbulun',
#   'merkezinde',
#   'telinizin',
#   'cekmemesi',
#   'sorunlarina',
#   'yonelin'],
#  ['edge',
#   'hizinda',
#   'internetin',
#   'allah',
#   'belasini',
#   'versin',
#   'turkcell',
#   'duy',
#   'sesimi'],
#  ['varmı',
#   'turkcellde',
#   'öyle',
#   'temsilci',
#   'sorun',
#   'çözemeyen',
#   'çözemezde',
#   'vatandası',
#   'sömürmek',
#   'üzerine',
#   'kurulu',
#   'düzende',
#   'başka',
#   'paket',
#   'sunalım'],
#  ['bosuna',
#   'okadar',
#   'kisi',
#   'calisiyor',
#   'orda',
#   'sen',
#   'hitap',
#   'ediliyor',
#   'turkcell',
#   'gbi',
#   'kuruma',
#   'yakismiyor'],
#  ['ay',
#   'önce',
#   'aldığım',
#   'telefonum',
#   'sonunda',
#   'bozuldu',
#   'kadar',
#   'dayanması',
#   'bile',
#   'mucize',
#   'teşekkürler',
#   'turkcell'],
#  ['gerzekalı', 'turkcell', 'cekmıo', 'babaannemde'],
#  ['dakika',
#   'icinde',
#   'turkcell',
#   'bana',
#   'tane',
#   'msg',
#   'attı',
#   'allahtan',
#   'bi',
#   'smsle',
#   'internet',
#   'paketimiz',
#   'bitti'],
#  ['girsin',
#   'ciksin',
#   'aveavodafone',
#   'kurus',
#   'turkcell',
#   'kurus',
#   'turkcell',
#   'show',
#   'tv',
#   'digiturk',
#   'karamehmetin',
#   'ilginc',
#   'dimi'],
#  ['birde',
#   'soracağım',
#   'durum',
#   'doğru',
#   'vadofone',
#   'turkcell',
#   'yalan',
#   'reklamdan',
#   'halkı',
#   'kandırmıyor',
#   'tüketici',
#   'hakkımız',
#   'yok'],
#  ['gece', 'saat', 'itibaryle', 'turkcellden', 'ayrılıyorum'],
#  ['dur',
#   'bi',
#   'mesaj',
#   'atıyımda',
#   'sevgilisinden',
#   'geldi',
#   'zannetsin',
#   'eheheheh',
#   'turkcell'],
#  ['alın',
#   'videoyu',
#   'izleyin',
#   'adil',
#   'kulanım',
#   'kota',
#   'koymak',
#   'afferin',
#   'size'],
#  ['turkcell', 'bana', 'fake', 'atıyo', 'hee'],
#  ['dklik',
#   'konusma',
#   'paketini',
#   'gunde',
#   'bitirebiliyormusum',
#   'turkcell',
#   'nasilda',
#   'salliyorr',
#   'nasil',
#   'bitebilir'],
#  ['istanbulun',
#   'yerinde',
#   'çeken',
#   'telefonum',
#   'ev',
#   'sinirlarina',
#   'girdigi',
#   'vakit',
#   'servis',
#   'yok',
#   'yazmasi',
#   'ilginç',
#   'birde',
#   'çekerdi',
#   'turkcell',
#   'hikayesin'],
# ...
#   'turkcell',
#   'kapsama',
#   'alani',
#   'olmayan',
#   'lik',
#   'alana',
#   'denk',
#   'gelmekkk',
#   'nedir'],
#  ['benim',
#   'gsm',
#   'alakasızlığım',
#   'olucak',
#   'turkcell',
#   'msj',
#   'yollamış',
#   'gündür',
#   'tl',
#   'yüklemiyormuşum',
#   'şikayetci',
#   'elimde',
#   'olsa',
#   'çöpe',
#   'atıcam',
#   'telefonuda'],
#  ['canım',
#   'msj',
#   'göndermiş',
#   'hediye',
#   'kazandın',
#   'msjlarına',
#   'itibar',
#   'etme',
#   'beni',
#   'seviyo',
#   'gelip',
#   'konuşmasını',
#   'beklesem',
#   'mi',
#   'ben',
#   'mi',
#   'teklif',
#   'etsem'],
#  ['bugün',
#   'eski',
#   'hattımı',
#   'geri',
#   'almak',
#   'istediğimi',
#   'söyleyince',
#   'hattımın',
#   'satışa',
#   'sunulduğunu',
#   'söylediler',
#   'turkcell',
#   'parasız',
#   'kaldı',
#   'hattımı',
#   'satıyor'],
#  ['neymis',
#   'efendim',
#   'turkcell',
#   'cekermis',
#   'uzerinden',
#   'heralde',
#   'telefon',
#   'faturasina',
#   'odedigim',
#   'paralar',
#   'haram',
#   'zikkim',
#   'olsn',
#   'hic',
#   'yerde',
#   'cekmyor'],
#  ['hattınız',
#   'turkcell',
#   'yalnız',
#   'değilsiniz',
#   'demektir',
#   'yoksa',
#   'hergün',
#   'düzenli',
#   'olarak',
#   'mesaj',
#   'gönderir'],
#  ['cocuk',
#   'oyuncağı',
#   'paketlerimi',
#   'bi',
#   'iptal',
#   'eden',
#   'bi',
#   'yenileyen',
#   'kuruluş'],
#  ['turkcell', 'isi', 'yokusa', 'sürüyo', 'pehh'],
#  ['hatların',
#   'sürekli',
#   'kesilmesi',
#   'tcell',
#   'göçügu',
#   'yoksa',
#   'iphone',
#   'kazığı',
#   'onu',
#   'çözemedim',
#   'kabus',
#   'bağlantılar'],
#  ['aralar', 'turkcell', 'bile', 'mesaj', 'atmiyor', 'derece', 'durum', 'kötü'],
#  ['turkcell',
#   'tv',
#   'projem',
#   'ilgilenmedinerede',
#   'musteri',
#   'memnuniyeti',
#   'girşimcilere',
#   'destek'],
#  ['sabahtan',
#   'beri',
#   'turkcell',
#   'müşteri',
#   'hizmetleriyle',
#   'kanka',
#   'oldum',
#   'amk',
#   'oraya',
#   'bağlıyo',
#   'oraya',
#   'hal',
#   'kalmadı',
#   'zaten',
#   'çalışcak'],
#  ['sayın',
#   'ciliv',
#   'bulunuduğum',
#   'yerde',
#   'turkcell',
#   'çekmiyor',
#   'reyhanlı',
#   'hataydan',
#   'yazıyorum',
#   'telefonla',
#   'konuşmak',
#   'bizim',
#   'eziyet',
#   'oluyor'],
#  ['beni', 'kucakladı', 'pess'],
#  ['modemin',
#   'metre',
#   'uzaklikta',
#   'olmasina',
#   'ragmen',
#   'baglanti',
#   'sorunu',
#   'yasanilan',
#   'insani',
#   'sinir',
#   'eden',
#   'tek',
#   'internet',
#   'superonline',
#   'fiber',
#   'olmali'],
#  ['bi', 'uyarsaydın', 'hani', 'turkcell'],
#  ['dedileristeğimi',
#   'şirketime',
#   'bildiridim',
#   'onlarda',
#   'superonline',
#   'müracatta',
#   'bulunmuşlar',
#   'süperonlinein',
#   'cevabı',
#   'saygısızca'],
#  ['sure',
#   'once',
#   'ben',
#   'ayni',
#   'durumdaydim',
#   'amac',
#   'nedir',
#   'bilniyorum',
#   'sonra',
#   'kesildi',
#   'aramalar'],
#  ['ay',
#   'oldu',
#   'rahatladim',
#   'korkulu',
#   'ruya',
#   'gormektense',
#   'uykusuz',
#   'kalirim'],
#  ['elveda', 'turkcell', 'yarın', 'seni', 'terk', 'ediyorum'],
#  ['evrakım',
#   'ödemem',
#   'tamam',
#   'telkapalıagır',
#   'hastam',
#   'varlanet',
#   'olsun',
#   'sana',
#   'turkcellölmek',
#   'istiyorummmm'],
#  ['turkcell',
#   'elinden',
#   'gelse',
#   'hattı',
#   'çıkartıp',
#   'tekrar',
#   'taksak',
#   'para',
#   'alıcak'],
#  ['in',
#   'iphone',
#   's',
#   'sloganı',
#   'cok',
#   'amotrce',
#   'olmusbugune',
#   'kadar',
#   'yapılmıs',
#   'iyi',
#   'iphone'],
#  ['iphone',
#   's',
#   'kampanyan',
#   'pahalı',
#   'be',
#   'turkcellim',
#   'bi',
#   'kerede',
#   'demediniz',
#   'al',
#   'ibocum',
#   'hediye',
#   'dağıtıyoruz',
#   'buda',
#   'bizden',
#   'sana'],
#  ['dizilerde',
#   'mesaj',
#   'geldiğinde',
#   'aaa',
#   'turkcellmiş',
#   'neyse',
#   'önemli',
#   'değil',
#   'repliği',
#   'kullanılsa',
#   'gerçekçi',
#   'olur',
#   'bence'],
#  ['bana',
#   'turkcell',
#   'in',
#   'gezenzi',
#   'ye',
#   'hala',
#   'yatirim',
#   'yaparak',
#   'neye',
#   'kastigini',
#   'soyleyebilir',
#   'mi',
#   'foursquare',
#   'sey',
#   'var'],
#  ['sevgili', 'paylasinca', 'guzel', 'demek', 'turkcell'],
#  ['eee',
#   'ünde',
#   'vodafone',
#   'geçişiniz',
#   'sağlannacak',
#   'dendi',
#   'turkcell',
#   'kapandı',
#   'an',
#   'itibariyle',
#   'vodafone',
#   'açılmadı',
#   'telefonsuz',
#   'kaldım',
#   'ulan'],
#  ['turkcell', 'cekmiyo', 'panpa'],
#  ['lan',
#   'turkcell',
#   'hic',
#   'liran',
#   'var',
#   'mi',
#   'sormuyosun',
#   'tlni',
#   'tl',
#   'yapalim',
#   'mi',
#   'demeyi',
#   'biliyosun'],
#  ['kişiyi',
#   'sesiyle',
#   'algılama',
#   'olayı',
#   'komik',
#   'önce',
#   'turkcell',
#   'beni',
#   'sesimden',
#   'tanır',
#   'demek',
#   'zorunda',
#   'kaldım'],
#  ['yalancı',
#   'superonline',
#   'aydır',
#   'sınırsız',
#   'olan',
#   'internt',
#   'hızını',
#   'düşürmeye',
#   'başladılar',
#   'kotasız',
#   'olan',
#   'bağlantımın',
#   'kotasını',
#   'aşmışım'],
#  ['yayında', 'inanılmaz', 'vizilti', 'varteknik', 'masalütfen', 'çözün'],
#  ['madem',
#   'bitti',
#   'yenilemesi',
#   'gerekir',
#   'turkcell',
#   'ilginç',
#   'mağdursun'],
#  ['ey',
#   'türkcell',
#   'cepten',
#   'internet',
#   'istiyoruz',
#   'kısa',
#   'zamanda',
#   'çözünüz'],
#  ['leventde',
#   'turkcell',
#   'g',
#   'yalan',
#   'avrupanın',
#   'hızlısı',
#   'buysa',
#   'avrupaya',
#   'acıdım',
#   'şimdi'],
#  ['dur',
#   'bi',
#   'mesaj',
#   'atıyımda',
#   'sevdiğinden',
#   'geldi',
#   'sansın',
#   'turkcell'],
#  ['lütfen', 'gece', 'den', 'sonra', 'bana', 'mesaj', 'atmaktan', 'vazgeç'],
#  ['iphone',
#   's',
#   'almak',
#   'icin',
#   'beklemekle',
#   'hata',
#   'mi',
#   'yaptim',
#   'hediye',
#   'verdiginiz',
#   'dk',
#   'kullandim',
#   'alamiyorum',
#   'sacmalik'],
#  ['pazartesi', 'sendromumu', 'sen', 'tetikleme', 'be', 'turkcell'],
#  ['valla',
#   'g',
#   'bile',
#   'cekmiyo',
#   'bazen',
#   'turkcell',
#   'aradm',
#   'gecen',
#   'telefon',
#   'cekmiyo',
#   'derken',
#   'yine',
#   'kesildigeri',
#   'bile',
#   'donmedilerrezalet'],
#  ['iletisim',
#   'uzerine',
#   'duygusal',
#   'reklami',
#   'yapiyorsun',
#   'iletisimi',
#   'saglayamiyorsun',
#   'illet',
#   'ettin',
#   'kac',
#   'gundur'],
#  ['bende', 'kazıkçı', 'turkcellliyim'],
#  ['oha', 'ara', 'tl', 'olmuş', 'valla', 'para', 'çekiyo', 'turkcell'],
#  ['chp',
#   'kafası',
#   'var',
#   'sende',
#   'pazar',
#   'senin',
#   'olacak',
#   'sanıyorsun',
#   'reklamındaki',
#   'bin',
#   'kişi',
#   'gitmiş',
#   'gider'],
#  ['böyle',
#   'giderse',
#   'ben',
#   'avea',
#   'akar',
#   'hacı',
#   'baydin',
#   'beni',
#   'turkcell'],
#  ['gunde', 'gb', 'nasil', 'biter', 'nasil', 'pis', 'turkcell'],
#  ['kahretsin', 'cok', 'artistim', 'turkcell', 'bana', 'espri', 'yapiyoor'],
#  ['gb',
#   'internet',
#   'yapiyorum',
#   'hala',
#   'internet',
#   'kullanimindan',
#   'param',
#   'gidiyo',
#   'aq',
#   'senin',
#   'ahhahahaha'],
#  ['online',
#   'işlem',
#   'merkezinizi',
#   'kontrol',
#   'etmenizi',
#   'rica',
#   'ediyorum',
#   'farklı',
#   'tarihlerde',
#   'işlem',
#   'yapmak',
#   'istedim',
#   'sorun',
#   'çıkartıyor'],
#  ['lanet', 'olsun', 'turkcell', 'kazikcinin', 'tekisin'],
#  ['buyuk',
#   'firsat',
#   'rumarali',
#   'turkcell',
#   'mesajlari',
#   'bi',
#   'gelirse',
#   'turkcelli',
#   'terkediyorum',
#   'geri',
#   'mesaj',
#   'bile',
#   'atmaya',
#   'calistim',
#   'düs',
#   'yakamdan',
#   'tcell'],
#  ['zamman',
#   'tunelını',
#   'ıptal',
#   'etmek',
#   'ıstıyorum',
#   'yardımcı',
#   'olurmusunuz'],
#  ['hayat',
#   'cebinizdekileri',
#   'bizle',
#   'paylaşınca',
#   'güzelselocanlara',
#   'bile',
#   'uyuzmwork',
#   'all',
#   'niteday',
#   'pay',
#   'th',
#   'bills',
#   'have',
#   'to',
#   'payaint',
#   'it',
#   'sad'],
#  ['turkcellin',
#   'çekmesi',
#   'gerçekten',
#   'baz',
#   'istasyonu',
#   'kurulması',
#   'gerekiyormuş'],
#  ['onun', 'bunun', 'cocugu', 'turkcelson', 'bır', 'haftaya', 'gırdı'],
#  ['bugün',
#   'herhangi',
#   'gün',
#   'tl',
#   'verip',
#   'saat',
#   'a',
#   'kadar',
#   'bol',
#   'bol',
#   'konuşmak',
#   'istemiyorum',
#   'turkcell'],
#  ['musteri',
#   'hizmetlerine',
#   'baglanirken',
#   'kere',
#   'turkcell',
#   'beni',
#   'sesimden',
#   'tanir',
#   'dedirttiler',
#   'kafayi',
#   'yemis',
#   'bunlar',
#   'demedi',
#   'demeyin'],
#  ['lan',
#   'sms',
#   'paketim',
#   'var',
#   'kontorumu',
#   'yiyosun',
#   'adi',
#   'turkcell',
#   'pislikler'],
#  ['aynısını',
#   'hafta',
#   'önce',
#   'ben',
#   'yazmıştım',
#   'paramızı',
#   'nelerde',
#   'kullanıyo',
#   'turkcell',
#   'içimizi',
#   'baymaya',
#   'evet'],
#  ['aralar',
#   'beynime',
#   'silah',
#   'dayayıp',
#   'zbufgüm',
#   'efektiyle',
#   'canıma',
#   'kıyarsam',
#   'paylaşıncağağğağa',
#   'çoğalan',
#   'şeklindeki',
#   'türksel',
#   'reklamından',
#   'olacak'],
#  ['internette',
#   'korsan',
#   'olarak',
#   'dizifilm',
#   'yayını',
#   'yapan',
#   'sitelerde',
#   'turkcell',
#   'kale',
#   'seramik',
#   'firmaların',
#   'video',
#   'reklamları',
#   'var',
#   'iş',
#   'şimdi'],
#  ['cok', 'firsatcisin', 'turkcell', 'cokk'],
#  ['adil',
#   'kullanim',
#   'hakki',
#   'denen',
#   'zimbirti',
#   'mbit',
#   'baglanti',
#   'kya',
#   'dusuyorsa',
#   'ben',
#   'burda',
#   'adillik',
#   'degil',
#   'adilik',
#   'ararim',
#   'turkcell'],
#  ['iyi',
#   'günler',
#   'turkcellden',
#   'arıyoruz',
#   'hakan',
#   'uçarla',
#   'görüşüyorumhayır',
#   'ben',
#   'değilimşöyle',
#   'bi',
#   'kampanyamız',
#   'ıııhhhhıggıı',
#   'ben',
#   'sonra',
#   'ulaşsam'],
#  ['caddede', 'bi', 'turkcell', 'bayii', 'son', 'kaalandi'],
#  ['in', 'pahalı', 'olması'],
#  ['olabilir',
#   'valla',
#   'benimki',
#   'turkcell',
#   'burada',
#   'baz',
#   'istasyonu',
#   'bile',
#   'yok',
#   'uzak'],
#  ['la',
#   'turkcell',
#   'delikanlı',
#   'bi',
#   'hat',
#   'olsa',
#   'reklamlarını',
#   'ali',
#   'poyrazo',
#   'seslendirmez',
#   'zaten'],
#  ['laaaaaan',
#   'golü',
#   'yedik',
#   'mobil',
#   'tv',
#   'gitti',
#   'ebeni',
#   'turkcell',
#   'ebeni',
#   'ligtv'],
#  ['şirketin',
#   'amaçlar',
#   'hiyerarşisi',
#   'vardır',
#   'vizyon',
#   'misyon',
#   'vs',
#   'turkcellin',
#   'misyonu',
#   'müşterilerinin',
#   'ırzına',
#   'geçmek'],
#  ['cocacolanın',
#   'yeni',
#   'reklamı',
#   'zamanki',
#   'güzel',
#   'olmuş',
#   'turkcellden',
#   'taklit',
#   'etmesini',
#   'bekliyorum',
#   'yakında',
#   'izleriz'],
#  ['milyon',
#   'tane',
#   'mesaj',
#   'hakkim',
#   'var',
#   'kullanamiyorum',
#   'special',
#   'thanks',
#   'to'],
#  ['dan', 'farklı'],
#  ['küçük',
#   'pakete',
#   'üye',
#   'olup',
#   'gold',
#   'paket',
#   'parası',
#   'ödemek',
#   'nedir',
#   'nedir',
#   'iyice',
#   'öztürkcelleşmişsiniz',
#   'maaşallah'],
#  ['g', 'calismiyor', 'turkcell', 'duy', 'beni'],
#  ['aydır',
#   'iptal',
#   'etmeye',
#   'çalıştığım',
#   'paketi',
#   'böyle',
#   'bi',
#   'paketiniz',
#   'bulunmayan',
#   'diyen',
#   'turkcell',
#   'gene',
#   'kazığı',
#   'çaktı',
#   'biyerlerime'],
#  ['hala', 'pahalısınız'],
#  ['coca',
#   'colanın',
#   'son',
#   'reklamı',
#   'güzelturkcellden',
#   'iyi',
#   'duygu',
#   'sömürüsü',
#   'yapmışlar'],
#  ['milleti',
#   'kandırmayın',
#   'lannn',
#   'turkcellvodafoneavea',
#   'ayaginizi',
#   'denk',
#   'alınnn'],
#  ['bırak',
#   'bis',
#   'nedir',
#   'ara',
#   'git',
#   'tcelle',
#   'faturayı',
#   'kesip',
#   'göndersin',
#   'hallederiz'],
#  ['benim',
#   'anlamadığım',
#   'otoparkın',
#   'katında',
#   'canavar',
#   'çeken',
#   'turkcell',
#   'vınn',
#   'kattaki',
#   'evimde',
#   'sürekli',
#   'tekliyor',
#   'ilginç',
#   'valla'],
#  ['hesabini',
#   'ergenler',
#   'mi',
#   'yonetiyordur',
#   'nedir',
#   'kurumsal',
#   'kimlik',
#   'falan'],
#  ['mesaj',
#   'olarak',
#   'bonus',
#   'turkcell',
#   'flexi',
#   'bbmden',
#   'bc',
#   'facebooktan',
#   'oyun',
#   'hediyeleri',
#   'allam',
#   'nolcak',
#   'benim',
#   'haliiim'],
#  ['mc',
#   'donaldsda',
#   'gnctrkcllin',
#   'menü',
#   'alana',
#   'menü',
#   'bedava',
#   'kampanyasından',
#   'faydalanan',
#   'anneleri',
#   'samimi',
#   'bulmuyorum'],
#  ['eger',
#   'bana',
#   'ulasamayan',
#   'varsa',
#   'bunun',
#   'nedeni',
#   'dir',
#   'is',
#   'bilmezlikleridir'],
#  ['den',
#   'tiksiniyorum',
#   'g',
#   'fln',
#   'hak',
#   'getire',
#   'artik',
#   'reklam',
#   'kampanyalariyla',
#   'insan',
#   'etkilemeye',
#   'calismaktan',
#   'bska',
#   'bi',
#   'yaradiklari',
#   'yokbiktik'],
#  ['coca',
#   'cola',
#   'turkcell',
#   'reklamları',
#   'sayesinde',
#   'herkes',
#   'fenafillah',
#   'olucak'],
#  ['abone',
#   'kaybından',
#   'sonra',
#   'elinde',
#   'li',
#   'hatları',
#   'bedava',
#   'dağıtmaya',
#   'başladı',
#   'yazık',
#   'sana',
#   'canım',
#   'yaa',
#   'çaresizliğin',
#   'son',
#   'noktası'],
#  ['bişey',
#   'soracın',
#   'internet',
#   'vınnların',
#   'hızlısı',
#   'iyi',
#   'çekeni',
#   'hankısıdır',
#   'turkcell',
#   'demeyin',
#   'bana',
#   'buz',
#   'soğurum',
#   'sizden',
#   'adını',
#   'anmiyacağım'],
#  ['kesnlikleee', 'turkcell', 'kapattr', 'hemen'],
#  ['ablacım',
#   'yorumlarıı',
#   'esirgeme',
#   'hayat',
#   'paylasınca',
#   'güzel',
#   'olsa',
#   'idi',
#   'onlarda',
#   'vicdan',
#   'olurdu'],
#  ['azından',
#   'müşteri',
#   'hizmetleri',
#   'ses',
#   'kayıtlarımı',
#   'vermezseniz',
#   'bile',
#   'çevirip',
#   'çevirip',
#   'dinlemenizi',
#   'tavsiye',
#   'ederim'],
#  ['size', 'savaş', 'acmış', 'hala', 'reklam', 'yapıyorsunuz'],
#  ['ibne',
#   'turkcell',
#   'somurdun',
#   'ulan',
#   'somurdun',
#   'sovuyorum',
#   'şimdi',
#   'sana',
#   'belli',
#   'değil'],
#  ['allah',
#   'belanızı',
#   'versinulan',
#   'acil',
#   'işim',
#   'olsa',
#   'kanser',
#   'edersiniz',
#   'adamı',
#   'ben',
#   'ses',
#   'tanıma',
#   'kaydı',
#   'yapmak',
#   'zorundamıyım',
#   'kardeşim'],
#  ['adil',
#   'kullanım',
#   'kandırmacasına',
#   'kaşı',
#   'açılan',
#   'davalarda',
#   'kaybetmeye',
#   'başladı',
#   'mağdursan',
#   'sende',
#   'dava',
#   'etbilgi'],
#  ['superonline', 'beni', 'sinir', 'ettin', 'aynen', 'yaa', 'deli', 'oldum'],
#  ['hayir',
#   'birde',
#   'telefon',
#   'edip',
#   'kontrol',
#   'edicez',
#   'diyip',
#   'hicbi',
#   'gelisme',
#   'olmuyo',
#   'devlet',
#   'dairesinde',
#   'burokrasi',
#   'sizde',
#   'beter',
#   'durumda'],
#  ['medyada',
#   'yer',
#   'alan',
#   'olumsuz',
#   'haberler',
#   'klasörünün',
#   'turkcell',
#   'genel',
#   'müdürü',
#   'süreyya',
#   'cilive',
#   'gösterilmediğini',
#   'düşünüyorum',
#   'ciddi',
#   'ciddi'],
#  ['beter', 'ol', 'turkcell', 'böyle', 'bişey', 'warmı', 'engellede', 'neymiş'],
#  ['sadece',
#   'ay',
#   'faturali',
#   'hat',
#   'kullananlara',
#   'iphone',
#   's',
#   'kampanyasi',
#   'yapiyosunuz',
#   'bugune',
#   'bugun',
#   'eksiye',
#   'dusmedim',
#   'istisna',
#   'istiyorum'],
#  ['carrier',
#   'iq',
#   'skandalı',
#   'hakkında',
#   'açıklama',
#   'yapmıyorsunuz',
#   'rt',
#   'yapalım',
#   'lütfen',
#   'zekeriya',
#   'beyaz'],
#  ['turkcell', 'yağlı', 'kurşunlara', 'gelesin', 'emiiiiii'],
#  ['hocam',
#   'bugun',
#   'memnuniyetsiz',
#   'musteriyim',
#   'tepiniyorum',
#   'kimse',
#   'orali',
#   'degilturkcell',
#   'uzuyon'],
#  ['sanırım',
#   'turkcel',
#   'bana',
#   'asık',
#   'satte',
#   'bana',
#   'tane',
#   'msj',
#   'attı'],
#  ['kendilerinden',
#   'haberleri',
#   'yok',
#   'turkcell',
#   'superonline',
#   'bolge',
#   'yetkili',
#   'bayisinin',
#   'beni',
#   'li',
#   'numaradan',
#   'aramasina',
#   'demeli'],
#  ['hayat',
#   'paylaşinca',
#   'güzel',
#   'hakli',
#   'olduğum',
#   'halde',
#   'hattimi',
#   'kapattiniz',
#   'hayati',
#   'paylaşamiyorum',
#   'sayenizde'],
#  ['sanirim', 'turkcell', 'beni', 'kazikladi'],
#  ['mesajsa', 'turkcelldir', 'arayansa', 'annemdir'],
#  ['avea',
#   'bak',
#   'sen',
#   'turkcell',
#   'hale',
#   'sokmus',
#   'bunlar',
#   'yuklu',
#   'tazmınat',
#   'odemek',
#   'ıstıyor',
#   'bellı',
#   'oldu',
#   'artık'],
#  ['ay',
#   'turkcell',
#   'faturamda',
#   'kendi',
#   'rekorumu',
#   'kırdım',
#   'heyoooo',
#   'ölçü',
#   'kullanmak',
#   'gerekirse',
#   'kol',
#   'dıt',
#   'dıt',
#   'dırıt',
#   'dıt'],
#  ['ohh',
#   'allaha',
#   'sukur',
#   'turkcell',
#   'selo',
#   'canlarina',
#   'yilbasi',
#   'reklami',
#   'yapmamiss',
#   'buyuk',
#   'eksiklikkk',
#   'anlatamam'],
#  ['la',
#   'ibne',
#   'internete',
#   'girenler',
#   'acep',
#   'turkiyeden',
#   'değil',
#   'mi',
#   'fiber',
#   'kablolar',
#   'götüne',
#   'girsin'],
#  ['yapsam',
#   'istek',
#   'gecersizdir',
#   'diyo',
#   'twitter',
#   'sokucam',
#   'once',
#   'twitter',
#   'sonra',
#   'turkcell'],
#  ['mecidiyeköyde',
#   'edge',
#   'asmalıda',
#   'edge',
#   'taksim',
#   'göbeği',
#   'katta',
#   'arşta',
#   'yine',
#   'edge',
#   'bazen',
#   'canımı',
#   'sıkıyorsun'],
#  ['avea',
#   'yalan',
#   'söylüyor',
#   'tamam',
#   'denilen',
#   'işleme',
#   'gün',
#   'sonra',
#   'olmaz',
#   'dediler',
#   'kendi',
#   'içinde',
#   'iletişim',
#   'kuramayanlar',
#   'müşteri',
#   'kursun'],
#  ['dakıka',
#   'oldu',
#   'hala',
#   'beklıyorum',
#   'cıdden',
#   'agzını',
#   'burnunu',
#   'kırıcam',
#   'turkcell'],
#  ['sms', 'sadakamiz', 'olsuntesyevden', 'cok', 'ihtiyaci', 'var', 'belli'],
#  ['kıymetimi',
#   'kaybettikten',
#   'sonra',
#   'anlicaksın',
#   'zamanımı',
#   'paramı',
#   'mutluluğumu',
#   'sömürdün',
#   'son',
#   'gün',
#   'seni',
#   'terkediyorum',
#   'turkcell',
#   'kib'],
#  ['sabah', 'mesaj', 'atan', 'turkcell', 'sapıkmısın', 'lan'],
#  ['dur', 'bi', 'mesaj', 'atayim', 'heyecanlansin', 'turkcell'],
#  ['sen',
#   'ondan',
#   'mesaj',
#   'beklersin',
#   'onun',
#   'yerine',
#   'turkcell',
#   'mesaj',
#   'atar',
#   'yaişte',
#   'öyle',
#   'berbat',
#   'yok'],
#  ['turkcelli',
#   'arayıp',
#   'isyan',
#   'edicem',
#   'şimdibikere',
#   'olsun',
#   'faturamı',
#   'gelmesi',
#   'gerektiği',
#   'yollamıyolar'],
#  ...]

# %%
sumTweetWords()
# Out:
# len(tweet_list) :  28919

# %%
print(tweet_list)
# Out:
# [['superonline', 'milyon', 'evin', 'kapisina', 'fiber', 'internet', 'goturdu', 'bizde', 'yok', 'bize', 'getirmiyorlar'], ['evde', 'olmamasi', 'gereken', 'şeyturkcell', 'digiturk', 'keriz', 'anten', 'çiçeği'], ['ucuz', 'iphone', 's', 'fiyatını', 'hangi', 'operatör', 'sunuyor', 'ohasın'], ['gb', 'internet', 'pakedim', 'bitti', 'lanet', 'turkcell'], ['ay', 'ben', 'size', 'tl', 'yakin', 'para', 'oduyorum', 'hizmet', 'istiyorum'], ['inceledimmm', 'kiyasladimm', 'gercktnn', 'cokk', 'yuksekk', 'rakiplerine', 'gore', 'bi', 'fiyatlarla', 'almak', 'akilkari', 'degl', 'sanrm'], ['lanet', 'olasın', 'turkcell', 'dedim'], ['dur', 'turkcelle', 'mesaj', 'atıyım', 'sevgilisinden', 'geldi', 'sansın', 'enayi'], ['gerçekten', 'ttnetden', 'hızlıysa', 'esos', 'geçecem', 'superonlinea', 'sinir', 'oldum', 'valla', 'kadar', 'yavaş', 'olamaz', 'birnet'], ['oc', 'musteri', 'hizmetleri', 'kukla', 'ettiniz', 'amk', 'turkcell', 'beni', 'sessimden', 'tanirmis'], ['bre', 'turkcell', 'tam', 'bi', 'hırsızsın', 'seni', 'bi', 'kullanani', 'esekler', 'kovalasin'], ['kardeşim', 'tanıdıgım', 'bi', 'piskiyatır', 'var', 'numarasını', 'vereyim', 'tansaşturkcellavea', 'vbden', 'gelen', 'mesajları', 'ona', 'atarsın'], ['oç', 'oldu', 'günde', 'bin', 'çisi', 'korkuttu', 'seni'], ['turkcellde', 'iyice', 'uçtu', 'yok', 'yükle', 'al', 'yükle', 'al', 'hesaplamalarıma', 'göre', 'bin', 'tl', 'yüklesem', 'şirketi'], ['canım', 'sevgilim', 'turkcell', 'yeter', 'artık', 'terket', 'beni', 'birinden', 'msj', 'beklediğim', 'bi', 'zaman', 'atarsın', 'msjlarını'], ['bende', 'turkcellliyim', 'bende', 'sevdadan', 'gram', 'yok'], ['ôyle', 'değil', 'iste', 'kısmen', 'anlatırım', 'geldigimde', 'ayrıntıları', 'turkcell', 'hattim', 'hala', 'iptal'], ['beşiktaşın', 'orta', 'yerindeyim', 'internet', 'edge', 'arada', 'edgeden', 'hallice', 'g', 'çekiyor', 'teşekkürler'], ['ipragaz', 'reklamı', 'muhteşem', 'olmuş', 'süper', 'abiturkcell', 'reklam', 'görsün'], ['yok', 'arasaniz', 'olacak', 'bilmiyorum', 'saattir', 'baglanti', 'kuramiyorum', 'yine', 'wifi', 'deyim', 'vinn', 'diyosunuz', 'kanser', 'olur', 'inssn'], ['bunların', 'böle', 'digiturk', 'turkcel', 'telekom', 'soyguncu'], ['turkcell', 'tam', 'kaltak'], ['yillik', 'tecrubeme', 'dayanarak', 'söyleyebilirim', 'yerde', 'çeker', 'büyük', 'yalan', 'turkcell', 'bakirköyde', 'cekmiyorgüneslide', 'hic', 'cekmiyor'], ['önce', 'bedava', 'dakikan', 'bitti', 'dedin', 'sonra', 'eksilmeyen', 'dk', 'verdin', 'şimdi', 'dakikan', 'kaldı', 'diyorsunnapmaya', 'çalışıyorsun', 'turkcell'], ['işim', 'gücüm', 'yok', 'turkcell', 'in', 'fizydeki', 'telefondan', 'sms', 'olarak', 'ücretsiz', 'şarkı', 'paylaşma', 'uygulamasını', 'deniyorum', 'hala', 'kimse', 'teşekkür', 'etmedi'], ['zaman', 'yoğun', 'şeyler', 'yaşasan', 'an', 'bi', 'msj', 'gelir', 'atan', 'turkcelldir'], ['inanır', 'mısınız', 'anda', 'internet', 'paketim', 'yok', 'hatta', 'tlmden', 'gitmiyor', 'turkcell', 'bizi', 'kazıklayacak', 'canım'], ['türksel', 'bugün', 'bildiğin', 'taciz', 'etti', 'beni', 'dk', 'rahat', 'vermedi'], ['zaman', 'turkcellin', 'yılbaşı', 'öztürkcell', 'reklamını', 'izle', 'iyice', 'dumur', 'ol', 'paralel', 'evrendeki', 'berbat', 'turkcellin', 'reklamı'], ['oyy', 'turkcel', 'sebekeneeee'], ['ısık', 'hızında', 'oldugunu', 'ıddıa', 'ettıklerı', 'ınternetı', 'gunde', 'baglayamıyorlar'], ['hesapla', 'haftalık', 'esenköy', 'tatili', 'turkcell', 'vınn', 'paketi', 'bana', 'nerdeyse', 'tlye', 'mal', 'olmuş', 'durumda', 'ehhayat', 'kazıklanınca', 'güzell', 'lalalalaa'], ['sacma', 'sapan', 'sinir', 'bozucu', 'reklam', 'furyasi', 'nedir', 'sahanli', 'turkcell', 'bonus', 'card', 'kafa', 'reklami', 'aytac', 'iticisiniz'], ['arada', 'süperonline', 'internet', 'gb', 'downloaddan', 'sonra', 'hızınıı', 'mbt', 'ten', 'mbt', 'düşürüyomuşhaberiniz', 'olasınırsız', 'gaza', 'gelmeyin'], ['turkcell', 'iyice', 'aştı', 'kendini', 'dakikada', 'mesaj', 'gönderilir', 'mi', 'insan', 'içlerinden', 'başkasındandır', 'umutlanıyor', 'insafsızlaaaaar'], ['oyle', 'cevap', 'yazdim', 'tcellesize', 'ihtiyacim', 'yok'], ['b ...

# %%
model = FastText(tweet_list, min_count=1)
# Out:
# 2018-10-06 02:10:12,598 : INFO : collecting all words and their counts
# 2018-10-06 02:10:12,600 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-10-06 02:10:12,613 : INFO : collected 11905 word types from a corpus of 28919 raw words and 3000 sentences
# 2018-10-06 02:10:12,614 : INFO : Loading a fresh vocabulary
# 2018-10-06 02:10:12,639 : INFO : min_count=1 retains 11905 unique words (100% of original 11905, drops 0)
# 2018-10-06 02:10:12,640 : INFO : min_count=1 leaves 28919 word corpus (100% of original 28919, drops 0)
# 2018-10-06 02:10:12,673 : INFO : deleting the raw counts dictionary of 11905 items
# 2018-10-06 02:10:12,674 : INFO : sample=0.001 downsamples 22 most-common words
# 2018-10-06 02:10:12,675 : INFO : downsampling leaves estimated 26821 word corpus (92.7% of prior 28919)
# 2018-10-06 02:10:13,836 : INFO : estimated required memory for 11905 words, 84755 buckets and 100 dimensions: 52329508 bytes
# 2018-10-06 02:10:13,839 : INFO : resetting layer weights
# 2018-10-06 02:10:14,427 : INFO : Total number of ngrams is 84755
# 2018-10-06 02:10:14,906 : INFO : training model with 3 workers on 11905 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-10-06 02:10:15,015 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:10:15,052 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:10:15,085 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:10:15,086 : INFO : EPOCH - 1 : training on 28919 raw words (26833 effective words) took 0.2s, 152731 effective words/s
# 2018-10-06 02:10:15,213 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:10:15,281 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:10:15,292 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:10:15,293 : INFO : EPOCH - 2 : training on 28919 raw words (26823 effective words) took 0.2s, 134271 effective words/s
# 2018-10-06 02:10:15,410 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:10:15,443 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:10:15,471 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:10:15,472 : INFO : EPOCH - 3 : training on 28919 raw words (26820 effective words) took 0.2s, 153783 effective words/s
# 2018-10-06 02:10:15,589 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:10:15,637 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:10:15,658 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:10:15,659 : INFO : EPOCH - 4 : training on 28919 raw words (26832 effective words) took 0.2s, 147183 effective words/s
# 2018-10-06 02:10:15,792 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-06 02:10:15,834 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-06 02:10:15,854 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-06 02:10:15,855 : INFO : EPOCH - 5 : training on 28919 raw words (26827 effective words) took 0.2s, 141406 effective words/s
# 2018-10-06 02:10:15,856 : INFO : training on a 144595 raw words (134135 effective words) took 0.9s, 141307 effective words/s
# 2018-10-06 02:10:15,857 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
print(model)
print("*"*50)
print(model.wv.vocab)
# Out:
# FastText(vocab=11905, size=100, alpha=0.025)
# **************************************************
# {'superonline': <gensim.models.keyedvectors.Vocab object at 0x7f4b46eeb710>, 'milyon': <gensim.models.keyedvectors.Vocab object at 0x7f4b46eeb668>, 'evin': <gensim.models.keyedvectors.Vocab object at 0x7f4b46e97978>, 'kapisina': <gensim.models.keyedvectors.Vocab object at 0x7f4b46e97908>, 'fiber': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d328d0>, 'internet': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32fd0>, 'goturdu': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d326d8>, 'bizde': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32710>, 'yok': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d327f0>, 'bize': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32be0>, 'getirmiyorlar': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d327b8>, 'evde': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32ef0>, 'olmamasi': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32320>, 'gereken': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32278>, 'şeyturkcell': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d329b0>, 'digiturk': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32b00>, 'keriz': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d32da0>, 'anten': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3bd30>, 'çiçeği': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3bd68>, 'ucuz': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3b630>, 'iphone': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3bdd8>, 's': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3ba20>, 'fiyatını': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3bc88>, 'hangi': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3ba90>, 'operatör': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d3bc18>, 'sunuyor': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5128>, 'ohasın': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea51d0>, 'gb': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5518>, 'pakedim': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5438>, 'bitti': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea52e8>, 'lanet': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5668>, 'turkcell': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5748>, 'ay': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5eb8>, 'ben': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5470>, 'size': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea57b8>, 'tl': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5f98>, 'yakin': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5d30>, 'para': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5908>, 'oduyorum': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5198>, 'hizmet': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5b00>, 'istiyorum': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5358>, 'inceledimmm': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5898>, 'kiyasladimm': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea5ac8>, 'gercktnn': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea94a8>, 'cokk': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9240>, 'yuksekk': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea96d8>, 'rakiplerine': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9b00>, 'gore': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9c50>, 'bi': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9cc0>, 'fiyatlarla': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9160>, 'almak': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9b38>, 'akilkari': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea99e8>, 'degl': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9f60>, 'sanrm': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9ef0>, 'olasın': <gensim.models.keyedvectors.Vocab object at 0x7f4b46ea9518>, 'dedim': <gensim.models.keyedvectors.Vocab object at 0x7f4b44d876d8>, 'dur': <gensim. ...

# %%
from tempfile import mkstemp

model_save_location = "3000tweetsfasttext.bin"
model.save(model_save_location)  # save the model
# Out:
# 2018-10-06 02:10:23,772 : INFO : saving FastText object under 3000tweetsfasttext.bin, separately None
# 2018-10-06 02:10:23,775 : INFO : not storing attribute vectors_norm
# 2018-10-06 02:10:23,776 : INFO : not storing attribute vectors_vocab_norm
# 2018-10-06 02:10:23,777 : INFO : not storing attribute vectors_ngrams_norm
# 2018-10-06 02:10:23,778 : INFO : not storing attribute buckets_word
# 2018-10-06 02:10:24,285 : INFO : saved 3000tweetsfasttext.bin

# %%
new_model = gensim.models.FastText.load(model_save_location)  # open the model
# Out:
# 2018-10-06 02:10:25,635 : INFO : loading FastText object from 3000tweetsfasttext.bin
# 2018-10-06 02:10:26,053 : INFO : loading wv recursively from 3000tweetsfasttext.bin.wv.* with mmap=None
# 2018-10-06 02:10:26,054 : INFO : setting ignored attribute vectors_norm to None
# 2018-10-06 02:10:26,055 : INFO : setting ignored attribute vectors_vocab_norm to None
# 2018-10-06 02:10:26,056 : INFO : setting ignored attribute vectors_ngrams_norm to None
# 2018-10-06 02:10:26,056 : INFO : setting ignored attribute buckets_word to None
# 2018-10-06 02:10:26,057 : INFO : loading vocabulary recursively from 3000tweetsfasttext.bin.vocabulary.* with mmap=None
# 2018-10-06 02:10:26,058 : INFO : loading trainables recursively from 3000tweetsfasttext.bin.trainables.* with mmap=None
# 2018-10-06 02:10:26,058 : INFO : loaded 3000tweetsfasttext.bin

# %%
words = list(new_model.wv.vocab)
print(words)
print("*"*50)
print(len(words))
# Out:
# ['superonline', 'milyon', 'evin', 'kapisina', 'fiber', 'internet', 'goturdu', 'bizde', 'yok', 'bize', 'getirmiyorlar', 'evde', 'olmamasi', 'gereken', 'şeyturkcell', 'digiturk', 'keriz', 'anten', 'çiçeği', 'ucuz', 'iphone', 's', 'fiyatını', 'hangi', 'operatör', 'sunuyor', 'ohasın', 'gb', 'pakedim', 'bitti', 'lanet', 'turkcell', 'ay', 'ben', 'size', 'tl', 'yakin', 'para', 'oduyorum', 'hizmet', 'istiyorum', 'inceledimmm', 'kiyasladimm', 'gercktnn', 'cokk', 'yuksekk', 'rakiplerine', 'gore', 'bi', 'fiyatlarla', 'almak', 'akilkari', 'degl', 'sanrm', 'olasın', 'dedim', 'dur', 'turkcelle', 'mesaj', 'atıyım', 'sevgilisinden', 'geldi', 'sansın', 'enayi', 'gerçekten', 'ttnetden', 'hızlıysa', 'esos', 'geçecem', 'superonlinea', 'sinir', 'oldum', 'valla', 'kadar', 'yavaş', 'olamaz', 'birnet', 'oc', 'musteri', 'hizmetleri', 'kukla', 'ettiniz', 'amk', 'beni', 'sessimden', 'tanirmis', 'bre', 'tam', 'hırsızsın', 'seni', 'kullanani', 'esekler', 'kovalasin', 'kardeşim', 'tanıdıgım', 'piskiyatır', 'var', 'numarasını', 'vereyim', 'tansaşturkcellavea', 'vbden', 'gelen', 'mesajları', 'ona', 'atarsın', 'oç', 'oldu', 'günde', 'bin', 'çisi', 'korkuttu', 'turkcellde', 'iyice', 'uçtu', 'yükle', 'al', 'hesaplamalarıma', 'göre', 'yüklesem', 'şirketi', 'canım', 'sevgilim', 'yeter', 'artık', 'terket', 'birinden', 'msj', 'beklediğim', 'zaman', 'msjlarını', 'bende', 'turkcellliyim', 'sevdadan', 'gram', 'ôyle', 'değil', 'iste', 'kısmen', 'anlatırım', 'geldigimde', 'ayrıntıları', 'hattim', 'hala', 'iptal', 'beşiktaşın', 'orta', 'yerindeyim', 'edge', 'arada', 'edgeden', 'hallice', 'g', 'çekiyor', 'teşekkürler', 'ipragaz', 'reklamı', 'muhteşem', 'olmuş', 'süper', 'abiturkcell', 'reklam', 'görsün', 'arasaniz', 'olacak', 'bilmiyorum', 'saattir', 'baglanti', 'kuramiyorum', 'yine', 'wifi', 'deyim', 'vinn', 'diyosunuz', 'kanser', 'olur', 'inssn', 'bunların', 'böle', 'turkcel', 'telekom', 'soyguncu', 'kaltak', 'yillik', 'tecrubeme', 'dayanarak', 'söyleyebilirim', 'yerde', 'çeker', 'büyük', 'yalan', 'bakirköyde', 'cekmiyorgüneslide', 'hic', 'cekmiyor', 'önce', 'bedava', 'dakikan', 'dedin', 'sonra', 'eksilmeyen', 'dk', 'verdin', 'şimdi', 'kaldı', 'diyorsunnapmaya', 'çalışıyorsun', 'işim', 'gücüm', 'in', 'fizydeki', 'telefondan', 'sms', 'olarak', 'ücretsiz', 'şarkı', 'paylaşma', 'uygulamasını', 'deniyorum', 'kimse', 'teşekkür', 'etmedi', 'yoğun', 'şeyler', 'yaşasan', 'an', 'gelir', 'atan', 'turkcelldir', 'inanır', 'mısınız', 'anda', 'paketim', 'hatta', 'tlmden', 'gitmiyor', 'bizi', 'kazıklayacak', 'türksel', 'bugün', 'bildiğin', 'taciz', 'etti', 'rahat', 'vermedi', 'turkcellin', 'yılbaşı', 'öztürkcell', 'reklamını', 'izle', 'dumur', 'ol', 'paralel', 'evrendeki', 'berbat', 'oyy', 'sebekeneeee', 'ısık', 'hızında', 'oldugunu', 'ıddıa', 'ettıklerı', 'ınternetı', 'gunde', 'baglayamıyorlar', 'hesapla', 'haftalık', 'esenköy', 'tatili', 'vınn', 'paketi', 'bana', 'nerdeyse', 'tlye', 'mal', 'durumda', 'ehhayat', 'kazıklanınca', 'güzell', 'lalalalaa', 'sacma', 'sapan', 'bozucu', 'furyasi', 'nedir', 'sahanli', 'bonus', 'card', 'kafa', 'reklami', 'aytac', 'iticisiniz', 'süperonline', 'downloaddan', 'hızınıı', 'mbt', 'ten', 'düşürüyomuşhaberiniz', 'olasınırsız', 'gaza', 'gelmeyin', 'aştı', 'kendini', 'dakikada', 'gönderilir', 'mi', 'insan', 'içlerinden', 'başkasındandır', 'umutlanıyor', 'insafsızlaaaaar', 'oyle', 'cevap', 'yazdim', 'tcellesize', 'ihtiyacim', 'turksel', 'dijiturkten', 'cektigim', 'kadaaar', 'denedim', 'bişeyi', 'paylaşmayı', 'sürekli', 'hata', 'verdi', 'vay', 'anasını', 'sıçıyım', 'internetine', 'liralarımı', 'sömürüyosun', 'gerizekalı', 'saat', 'fark', 'etmeden', 'atana', 'denir', 'turkcelli', 'kiniyorum', 'ipad', 'icin', 'yapmis', 'oldugunuz', 'kampanyanin', 'sadece', 'faturali', 'hatlar', 'gecerli', 'olmasi', 'durum', 'cok', 'ii', 'sankiher', 'paketlerinin', 'kati', 'geliosurekli', 'yuksek', 'paket', 'almaya', 'mecbur', 'birakiosun', 'bütün', 'turkcellilerde', 'hayat', 'paylaşınca', 'güzel', 'çalıyor', 'hoşuma', 'giden', 'müzikten', 'midem', 'bulanmaya', 'başladı', 'so ...
# **************************************************
# 11905

# %%
print(new_model['mutlu'])
# Out:
# [-5.48144244e-03  8.05438589e-03 -1.32501237e-02  8.81713908e-03
#  -2.25643255e-02 -3.74181271e-02 -3.59413438e-02 -7.19454288e-02
#  -2.92859171e-02  1.65181130e-03  1.14965085e-02  4.63127866e-02
#   2.50046048e-02 -5.10345846e-02  2.74167694e-02 -5.58696920e-03
#  -8.00183639e-02  1.16453201e-01  7.17975758e-03  1.81133777e-03
#  -2.45191641e-02  2.93840989e-02  5.19247800e-02 -3.98179097e-03
#   4.45192382e-02 -1.59900077e-02  2.46079676e-02  4.56962623e-02
#   5.19592054e-02  2.17811130e-02 -4.48312014e-02 -8.30333009e-02
#  -2.69322004e-03  1.15909772e-02 -1.07042305e-02  6.66394308e-02
#  -6.52080700e-02 -4.61780205e-02 -5.71883321e-02 -6.86856825e-03
#  -5.26978262e-02  8.70079175e-03  8.32601727e-05 -3.67475711e-02
#   3.29264812e-02  4.81679924e-02 -3.14167514e-02  4.16555405e-02
#   2.99990969e-03 -3.09640425e-03 -5.10648042e-02 -8.41384977e-02
#   6.05177647e-03 -6.65590912e-02  3.46123544e-03  8.57619196e-02
#   3.03940289e-02 -2.68636327e-02 -5.13000740e-03 -7.02221296e-04
#   4.82758768e-02  1.89284142e-02 -3.90947983e-02 -2.02373546e-02
#   8.18565115e-03 -7.76596069e-02  2.10162997e-03 -1.76193547e-02
#   6.33870298e-03  2.11410094e-02 -3.46309692e-02  1.90643854e-02
#  -3.54910046e-02 -2.17003450e-02  2.36739032e-02 -5.10657243e-02
#   5.21883443e-02 -3.45351920e-02  8.13470036e-03 -1.22501934e-03
#  -1.04870480e-02 -1.29050789e-02  4.91230488e-02 -4.77989279e-02
#   2.84728445e-02 -9.07278061e-02  2.90030502e-02  1.99271788e-04
#  -3.47463712e-02  8.33899304e-02  1.38004934e-02 -1.67261437e-02
#  -4.58711497e-02  4.50210944e-02 -3.28388289e-02  5.22108860e-02
#   8.39979574e-02 -2.10690293e-02 -4.23958041e-02  5.34825362e-02]
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
# We will also need to get the words closest to a word
model.similar_by_word('fatura',topn=50)
# Out:
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
# [('faturaya', 0.9999796748161316),
#  ('faturası', 0.999977171421051),
#  ('faturan', 0.9999763369560242),
#  ('faturam', 0.9999758005142212),
#  ('faturasini', 0.9999758005142212),
#  ('faturada', 0.9999756813049316),
#  ('faturadan', 0.9999751448631287),
#  ('faturayı', 0.9999750852584839),
#  ('faturaa', 0.9999744892120361),
#  ('faturasını', 0.9999736547470093),
#  ('faturasina', 0.9999730587005615),
#  ('faturaniz', 0.9999721050262451),
#  ('faturasız', 0.999971866607666),
#  ('faturamda', 0.9999717473983765),
#  ('faturalarını', 0.9999716877937317),
#  ('faturalı', 0.9999711513519287),
#  ('faturama', 0.9999706745147705),
#  ('faturanizda', 0.9999704957008362),
#  ('faturanın', 0.9999701976776123),
#  ('faturami', 0.9999699592590332),
#  ('faturasızlar', 0.9999687671661377),
#  ('faturalarımla', 0.999968409538269),
#  ('faturasımı', 0.999968409538269),
#  ('faturalarının', 0.9999679923057556),
#  ('faturali', 0.9999678730964661),
#  ('faturamı', 0.9999673366546631),
#  ('faturasi', 0.9999669790267944),
#  ('faturamın', 0.9999663829803467),
#  ('faturalarıda', 0.999964714050293),
#  ('faturayla', 0.9999620914459229),
#  ('faturalandırma', 0.9999606609344482),
#  ('faturayi', 0.9999595880508423),
#  ('kariladiturkcell', 0.9999591708183289),
#  ('öztürkcell', 0.9999584555625916),
#  ('ozturkcell', 0.9999582767486572),
#  ('çinturkcell', 0.9999576210975647),
#  ('birturkcell', 0.9999573826789856),
#  ('turkcellliyim', 0.9999571442604065),
#  ('katılıyormturkcell', 0.9999570846557617),
#  ('yapturkcell', 0.9999570250511169),
#  ('kendisiniturkcell', 0.9999570250511169),
#  ('bankaturkcell', 0.9999570250511169),
#  ('degilturkcell', 0.9999566674232483),
#  ('turkcellbiri', 0.9999566674232483),
#  ('diilturkcell', 0.9999566674232483),
#  ('soyluyorturkcell', 0.9999566078186035),
#  ('denemiyorsun', 0.9999566078186035),
#  ('turkcellbok', 0.9999565482139587),
#  ('özturkcell', 0.9999565482139587),
#  ('turkcell', 0.999956488609314)]

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline


def display_closestwords_tsnescatterplot(model, word):
    
    arr = np.empty((0,100), dtype='f')
    word_labels = [word]

    # get close words
    close_words = model.similar_by_word(word)
    
    # add the vector for each of the closest words to the array
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    # find tsne coords for 2 dimensions
    tsne = TSNE(n_components=2, random_state=0)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    # display scatter plot
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
    plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
    plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()
    
display_closestwords_tsnescatterplot(new_model, 'süperonline')
# Out:
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   del sys.path[0]
# 2018-10-06 02:11:00,941 : INFO : precomputing L2-norms of word weight vectors
# 2018-10-06 02:11:00,946 : INFO : precomputing L2-norms of ngram weight vectors
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   app.launch_new_instance()
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# reference : https://medium.com/@aneesha/using-tsne-to-plot-a-subset-of-similar-words-from-word2vec-bb8eeaea6229

# %%
w2v_model = new_model

# %%
from __future__ import absolute_import, division, print_function
import numpy as np
count = 100  #len(w2v_model.wv.vocab)
word_vectors_matrix = np.ndarray(shape=(count, 100), dtype='float64')
word_list = []
i = 0
for word in (w2v_model.wv.vocab):
    word_vectors_matrix[i] = w2v_model[word]
    word_list.append(word)
    i = i+1
    if i == count:
        break
print("word_vectors_matrix shape is ", word_vectors_matrix.shape)
# Out:
# word_vectors_matrix shape is  (100, 100)
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
#Compress the word vectors into 2D space
import sklearn.manifold
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)
word_vectors_matrix_2d = tsne.fit_transform(word_vectors_matrix)
print("word_vectors_matrix_2d shape is ", word_vectors_matrix_2d.shape)
# Out:
# word_vectors_matrix_2d shape is  (100, 2)

# %%
#Compress the word vectors into 2D space
import sklearn.manifold
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)
word_vectors_matrix_2d = tsne.fit_transform(word_vectors_matrix)
print("word_vectors_matrix_2d shape is ", word_vectors_matrix_2d.shape)
# Out:
# word_vectors_matrix_2d shape is  (100, 2)

# %%
import pandas as pd
points = pd.DataFrame(
    [
        (word, coords[0], coords[1]) 
        for word, coords in [
            (word, word_vectors_matrix_2d[word_list.index(word)])
            for word in word_list
        ]
    ],
    columns=["word", "x", "y"]
)
print("Points DataFrame built")
# Out:
# Points DataFrame built

# %%
points.head(10)
# Out:
#           word         x          y
# 0  superonline -5.918034  -7.216752
# 1       milyon  5.375295 -11.422393
# 2         evin  1.120179  -9.352382
# 3     kapisina  0.393974  -8.873714
# 4        fiber  0.597361  -9.244160
# 5     internet -5.686086  -7.306945
# 6      goturdu  4.850082 -11.135590
# 7        bizde -3.429439  -8.109622
# 8          yok -5.495710  -7.367470
# 9         bize -1.664210  -8.364365

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) &
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1]) 
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
plot_region(x_bounds=(-60.2, 60.2), y_bounds=(-60.2, 60.0))

# %% [markdown]
# reference : https://github.com/MiguelSteph/word2vec-with-gensim/blob/master/word2vec_model_visualization.ipynb

# %%
result = model.most_similar(positive=['sinir', 'ucuz'], negative=['musteri'], topn=1)
result
# Out:
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('türkülü', 0.9991411566734314)]

# %%
new_model.similarity('türkcell','kampanya')
# Out:
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9999537340544857

# %%
new_model.n_similarity(['ucuz', 'sinir'], ['lanet', 'hizmetleri'])
# Out:
# /home/halil/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9998852002978452
